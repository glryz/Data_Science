# %% [markdown]
# # Keras Classification

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (12,6)
# plt.rcParams['figure.dpi'] = 100
sns.set_style("whitegrid")
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

# %%
cancer.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
print(cancer["DESCR"])
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         worst/largest values) of these features were computed for each image,
# ...

# %%
cancer["feature_names"]
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
df_feat = pd.DataFrame(cancer['data'],columns=cancer['feature_names'])
df_feat.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0       17.990        10.380         122.800   1001.000            0.118
# 1       20.570        17.770         132.900   1326.000            0.085
# 2       19.690        21.250         130.000   1203.000            0.110
# 3       11.420        20.380          77.580    386.100            0.142
# 4       20.290        14.340         135.100   1297.000            0.100
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.278           0.300                0.147          0.242
# 1             0.079           0.087                0.070          0.181
# 2             0.160           0.197                0.128          0.207
# 3             0.284           0.241                0.105          0.260
# 4             0.133           0.198                0.104          0.181
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
df_target = pd.DataFrame(cancer['target'],columns=['Cancer'])
df_target.head()
# Out:
#    Cancer
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
frames = [df_feat, df_target]
df = pd.concat(frames,axis=1)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0       17.990        10.380         122.800   1001.000            0.118
# 1       20.570        17.770         132.900   1326.000            0.085
# 2       19.690        21.250         130.000   1203.000            0.110
# 3       11.420        20.380          77.580    386.100            0.142
# 4       20.290        14.340         135.100   1297.000            0.100
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.278           0.300                0.147          0.242
# 1             0.079           0.087                0.070          0.181
# 2             0.160           0.197                0.128          0.207
# 3             0.284           0.241                0.105          0.260
# 4             0.133           0.198                0.104          0.181
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.shape
# Out:
# (569, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe().T
# Out:
#                           count    mean     std     min     25%     50%  \
# mean radius             569.000  14.127   3.524   6.981  11.700  13.370
# mean texture            569.000  19.290   4.301   9.710  16.170  18.840
# mean perimeter          569.000  91.969  24.299  43.790  75.170  86.240
# mean area               569.000 654.889 351.914 143.500 420.300 551.100
# mean smoothness         569.000   0.096   0.014   0.053   0.086   0.096
# mean compactness        569.000   0.104   0.053   0.019   0.065   0.093
# mean concavity          569.000   0.089   0.080   0.000   0.030   0.062
# mean concave points     569.000   0.049   0.039   0.000   0.020   0.034
# mean symmetry           569.000   0.181   0.027   0.106   0.162   0.179
# mean fractal dimension  569.000   0.063   0.007   0.050   0.058   0.062
# radius error            569.000   0.405   0.277   0.112   0.232   0.324
# texture error           569.000   1.217   0.552   0.360   0.834   1.108
# ...

# %%
df.Cancer.value_counts()
# Out:
# 1    357
# 0    212
# Name: Cancer, dtype: int64

# %%
sns.countplot(df["Cancer"])

# balance bir data
# Out:
# <AxesSubplot:xlabel='Cancer', ylabel='count'>

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True);

# %%
drop_list = ["worst perimeter", "worst area", "perimeter error", "area error", "mean perimeter", "mean area"]

# multicolinarity olan feature ları sildim.

# %%
df=df.drop(drop_list, axis=1)

# %%
df.shape
# Out:
# (569, 25)

# %%
plt.figure(figsize = (8,10))
df.corr()['Cancer'].sort_values().drop("Cancer").plot(kind = "barh");

# %% [markdown]
# ## Preprocessing of Data
# - Train | Test Split, Scalling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X = df.drop('Cancer', axis=1)
y = df['Cancer'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, test_size = 0.10, random_state = 42)

# %%
scaler = MinMaxScaler()

# verileri daha dar bir aralığa topladığı için ve daha hız kazandırdığı için MinMaxScaler tercih nedeni.

# %%
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# fit'i X_train ile, transform u X_test ile yapıyorum, data leakege ı önleme adına.

# %% [markdown]
# ## Modelling & Model Performance

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_roc_curve, roc_auc_score, roc_curve
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV

# %%
X_train.shape
# Out:
# (512, 24)

# %%
X_test.shape
# Out:
# (57, 24)

# %%
model = Sequential()

model.add(Dense(30, activation = "relu"))  # sigunt ve hiperb. e göre öğrenme daha fazla olduğu için relu kullandık.
model.add(Dense(15, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))  # output binary olduğu için sigmoid kullandık. 

model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])

# 24 feature için nöron sayısını 30 a çıkarttım. sonra ikinci layerda 15 e düşürdüm. 
# çıktı da 1 (. üçgen oluşturmayı tercih ettim.
# sigmoid aynı zamanda logistic fonksiyondu ve datayı 0 ile 1 arasına sıkıştırıyordu. çıkış layer da bunu kullanmam daha doğru olur.
# çıkış binary olduğundan, loss metriği olarak binarı_crossentropy kullandım.

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 1000, verbose=1)

# eğitim için kullanılacak datanın %10 luk bölümünü ayırdık. onu hiç bir şekilde eğitime sokmuyoruz. onu validasyon yaparken kullanacak.
# Out:
# Epoch 1/1000
# 15/15 [==============================] - 1s 11ms/step - loss: 0.6799 - accuracy: 0.6391 - val_loss: 0.6734 - val_accuracy: 0.5192
# Epoch 2/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6499 - accuracy: 0.7326 - val_loss: 0.6447 - val_accuracy: 0.7500
# Epoch 3/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6214 - accuracy: 0.8174 - val_loss: 0.6128 - val_accuracy: 0.7885
# Epoch 4/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5841 - accuracy: 0.8630 - val_loss: 0.5641 - val_accuracy: 0.8462
# Epoch 5/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5400 - accuracy: 0.8870 - val_loss: 0.5134 - val_accuracy: 0.9038
# Epoch 6/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4906 - accuracy: 0.8826 - val_loss: 0.4600 - val_accuracy: 0.9038
# Epoch 7/1000
# ...

# %%
model.summary()

# 1000 x 15 iterasyon oldu.
# her iterasyonda 1231 tane parametre güncellemesi yapıldı.
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 30)                750
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 16
# ...
# Total params: 1,231
# Trainable params: 1,231
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()

# loss ve val_loss iterasyonlar ilerledikçe aşağıya doğru azaldı. 
# accuracy ve val_accurasy değeri de tabi ki artıyor.
# Out:
#    loss  accuracy  val_loss  val_accuracy
# 0 0.680     0.639     0.673         0.519
# 1 0.650     0.733     0.645         0.750
# 2 0.621     0.817     0.613         0.788
# 3 0.584     0.863     0.564         0.846
# 4 0.540     0.887     0.513         0.904

# %%
loss_df.plot();

# 200 değerinden sonra overfit e gitmiş.

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# [0.5005191564559937, 0.859649121761322]

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("accuracy : ", accuracy)
# Out:
# loss :  0.5005191564559937
# accuracy :  0.859649121761322

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")   # 1 olma ihtimali 0.5 ten büyükse 1 yap
#y_pred = model.predict_classes(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[19  2]
#  [ 6 30]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.90      0.83        21
#            1       0.94      0.83      0.88        36
#
#     accuracy                           0.86        57
#    macro avg       0.85      0.87      0.85        57
# weighted avg       0.87      0.86      0.86        57

# %% [markdown]
# ### EarlyStopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential()

model.add(Dense(30, activation = "relu"))
model.add(Dense(15, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
#The patience is often set somewhere between 10 and 100 (10 or 20 is more common), 
#but it really depends on your dataset and network.

# %% [raw]
# soru: başta eğitim oldu, sonra bozuldu ve son 25 te eğitim olmadığı için earlystop durdurdu. peki daha sonra iyileşme ihtimali yok mu ki orada durduruyoruz? başka türlü sorarasak, epochs ların içinde en iyi olanı seçme seçeneğimiz yok mu?
#
# cevap: seçilecek patience önemli bu noktada. belki ileride iyileşme olacaktı ama siz erken keserseniz skor daha düşük çıkar. o yüzden patience değerini uygun seçmek önemli. vereceğiniz değer ile skoru sınırlandırıyor olabilirsiniz

# %%
early_stop = EarlyStopping(monitor = "val_loss", mode = "auto", verbose = 1, patience = 15)

# EarlyStop kullanarak az önceki overfittingin önüne geçeceğiz.

# earlystop hangi değişkeni monitör edecek, val_loss.
# kaç epochs sabredecek, 15

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 1000, verbose = 1,
          callbacks = [early_stop])

# train setimin sondaki %10 unu ayırdık.
# Out:
# Epoch 1/1000
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6622 - accuracy: 0.5739 - val_loss: 0.6176 - val_accuracy: 0.8654
# Epoch 2/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6256 - accuracy: 0.8370 - val_loss: 0.5910 - val_accuracy: 0.9615
# Epoch 3/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5915 - accuracy: 0.8891 - val_loss: 0.5573 - val_accuracy: 0.9423
# Epoch 4/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5535 - accuracy: 0.8761 - val_loss: 0.5212 - val_accuracy: 0.9423
# Epoch 5/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5132 - accuracy: 0.8957 - val_loss: 0.4721 - val_accuracy: 0.9423
# Epoch 6/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4682 - accuracy: 0.9022 - val_loss: 0.4264 - val_accuracy: 0.9423
# Epoch 7/1000
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot();

# earlystop kullanarak overfittinge girmeden eğitimi durdurmasını sağladık.

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
#y_pred = model.predict_classes(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# modelimin skorunu alırken (validation yaparken) train setindeki ayırdığım %10 ile değil, başta ana datamdan ayırdığım test seti ile yapıyorum.
# model.fit yaparken kullandığımız validation_split ile alınan skorla karıştırmayalım.
# Out:
# [[20  1]
#  [ 2 34]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        21
#            1       0.97      0.94      0.96        36
#
#     accuracy                           0.95        57
#    macro avg       0.94      0.95      0.94        57
# weighted avg       0.95      0.95      0.95        57

# %% [markdown]
# ### learning_rate

# %%
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

model.add(Dense(30, activation = "relu"))
model.add(Dense(15, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

opt = Adam(lr = 0.005)
model.compile(optimizer = opt, loss = "binary_crossentropy", metrics = ["accuracy"])

#  learning rate ile eğimi çarpıyorduk ve bu bize atacağımız adımın büyüklüğünü veriyordu.
# şimdi adımlarım daha büyüyecek.

# %%
early_stop = EarlyStopping(monitor = "val_loss", mode = "auto", verbose = 1, patience = 15)

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 1000, verbose = 1,
          callbacks = [early_stop])
# Out:
# Epoch 1/1000
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6537 - accuracy: 0.6522 - val_loss: 0.5833 - val_accuracy: 0.8462
# Epoch 2/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4952 - accuracy: 0.8870 - val_loss: 0.3793 - val_accuracy: 0.9038
# Epoch 3/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3192 - accuracy: 0.8935 - val_loss: 0.1856 - val_accuracy: 0.9615
# Epoch 4/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2153 - accuracy: 0.9196 - val_loss: 0.1299 - val_accuracy: 0.9423
# Epoch 5/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1651 - accuracy: 0.9391 - val_loss: 0.0749 - val_accuracy: 1.0000
# Epoch 6/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1409 - accuracy: 0.9413 - val_loss: 0.0761 - val_accuracy: 0.9808
# Epoch 7/1000
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()

# learning rate ile adımlarımı büyüttüğüm için skorda dalgalanma oldu. bu beklenen bir sonuç.
# Out:
# <AxesSubplot:>

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
#y_pred = model.predict_classes(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[19  2]
#  [ 0 36]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        21
#            1       0.95      1.00      0.97        36
#
#     accuracy                           0.96        57
#    macro avg       0.97      0.95      0.96        57
# weighted avg       0.97      0.96      0.96        57

# %% [markdown]
# ### Dropout

# %% [markdown]
# The Dropout layer randomly sets input units to 0 with a frequency of `rate`
# at each step during training time, which helps prevent overfitting.

# %%
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()

model.add(Dense(30, activation="relu"))
model.add(Dropout(0.5))                   # her seferinde random şekilde nöronların yarısını kapatacak.
model.add(Dense(15, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation="sigmoid"))

opt = Adam(lr = 0.001)
model.compile(optimizer = opt, loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 1000, verbose = 1)
# Out:
# Epoch 1/1000
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6870 - accuracy: 0.6261 - val_loss: 0.6967 - val_accuracy: 0.5000
# Epoch 2/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6711 - accuracy: 0.6087 - val_loss: 0.6879 - val_accuracy: 0.5000
# Epoch 3/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6598 - accuracy: 0.6370 - val_loss: 0.6795 - val_accuracy: 0.5000
# Epoch 4/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6468 - accuracy: 0.6696 - val_loss: 0.6690 - val_accuracy: 0.5000
# Epoch 5/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6303 - accuracy: 0.6543 - val_loss: 0.6531 - val_accuracy: 0.5000
# Epoch 6/1000
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6199 - accuracy: 0.6935 - val_loss: 0.6300 - val_accuracy: 0.5000
# Epoch 7/1000
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()

# görüldüğü gibi earlystop kullanmadan sadece Dropout ile overfitting i düşürdük.
# Out:
# <AxesSubplot:>

# %% [raw]
# Dropout ile skordan bir miktar feragat ederek overfitting i engellemiş olduk. fakat eğitimde epochs ların tüm iterasyonlarını tamamlamasını sağladık.
#
# belki de nöron sayısını azaltmamıza rağmen arada büyük fark olmamasının nedeni eğitimi sonuna kadar devam ettiriyor olmamız.
#
# fakat en kolayı earlystop kullanmak. hoca derste bunu tavsiye etti.

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
#y_pred = model.predict_classes(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[20  1]
#  [ 4 32]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.89        21
#            1       0.97      0.89      0.93        36
#
#     accuracy                           0.91        57
#    macro avg       0.90      0.92      0.91        57
# weighted avg       0.92      0.91      0.91        57

# %% [markdown]
# ## Cross Validation

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(units = 30, activation = 'relu'))
    classifier.add(Dense(units = 15, activation = 'relu'))
    classifier.add(Dense(units = 1, activation = 'sigmoid'))
    classifier.compile(optimizer = "adam", loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier

# %%
classifier = KerasClassifier(build_fn = build_classifier, batch_size = 32, epochs = 100, verbose=0)

scores = cross_validate(estimator = classifier, X = X_train, y = y_train,
                        scoring = ['accuracy', 'precision', 'recall', 'f1'], cv = 10)

df_scores = pd.DataFrame(scores, index = range(1, 11)).iloc[:, 2:]

df_scores_summary = pd.DataFrame({"score_mean" : df_scores.mean().values, "score_std" : df_scores.std().values},
                                 index = ["acc", "pre", "rec", "f1"])

df_scores_summary

# bu yöntemde EarlyStop uygulayamıyoruz. 
# o yüzden edindiğimiz tecrübeye göre ortalama 100 epochs da overfittig e girmediğini bildiğim için epochs u 100 olarak belirledim.
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000195136B0948> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %% [raw]
# cv = 10 olarak belirlemiştim.
# standart dev.lar çok düşük dolayısıyla skorlarım her crossvalidation da birbirine yakın.
# dolayısıyla datamın skorları bu değerler diyebilirim.

# %% [markdown]
# ## GridSearchCV

# %%
def build_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(units = 30, activation = 'relu'))
    classifier.add(Dense(units = 15, activation = 'relu'))
    classifier.add(Dense(units = 1, activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier

# %%
early_stop = EarlyStopping(monitor = "accuracy", mode = "auto", verbose = 1, patience = 15)

# %%
classifier = KerasClassifier(build_fn = build_classifier, epochs = 200)
parameters = {'batch_size': [32, 64],
              'optimizer': ['adam', 'rmsprop', "SGD", "adagrad", "adadelta"]}
grid_model = GridSearchCV(estimator = classifier,
                          param_grid = parameters,
                          scoring = 'accuracy',
                          cv = 10,
                          n_jobs = -1,
                          verbose = 1)
grid_model.fit(X_train, y_train, callbacks = [early_stop])
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Epoch 1/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.7105 - accuracy: 0.4473
# Epoch 2/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6596 - accuracy: 0.7480
# Epoch 3/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6104 - accuracy: 0.8164
# Epoch 4/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5607 - accuracy: 0.8613
# Epoch 5/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.5069 - accuracy: 0.8848
# Epoch 6/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4497 - accuracy: 0.8906
# Epoch 7/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3950 - accuracy: 0.8984
# Epoch 8/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3474 - accuracy: 0.9102
# Epoch 9/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3096 - accuracy: 0.9141
# ...

# %%
grid_model.best_score_
# Out:
# 0.9745852187028659

# %%
grid_model.best_params_
# Out:
# {'batch_size': 32, 'optimizer': 'adam'}

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for grid_model

# %% [markdown]
# #### for keras models

# %%
y_pred_proba = model.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot([0,1],[0,1],'k--')            # DL de ROC'u manuel olarak plotluyoruz.
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('ROC curve')
plt.show()

# ML de skorları otomatik alıyordu. burada manuel olarak giriyoruz.

# %% [raw]
# "Olasılık" değerleriyle ROC Curve çizilir. 1 lerle 0 larla değil.
#
# dolayısıyla burada y_pred_proba = model.predict(X_test) ile olasılık değerlerini alıyorum.
# Buradaki predict fonksiyonu sadece 1 olma olasılığını veriyor.

# %%
roc_auc_score(y_test, y_pred_proba)
# Out:
# 0.988095238095238

# %% [markdown]
# #### for gridsearchcv model

# %%
y_pred_proba = grid_model.predict_proba(X_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot([0,1],[0,1],'k--')                 
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('ROC curve')
plt.show()

# %%
roc_auc_score(y_test, y_pred_proba)
# Out:
# 0.9907407407407407

# %% [markdown]
# ## Saving Final Model and Scaler

# %%
import pickle
pickle.dump(scaler, open("scaler_cancer", 'wb'))

# %%
model = Sequential()

model.add(Dense(30, activation = "relu"))
model.add(Dense(15, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
early_stop = EarlyStopping(monitor = "val_loss", mode = "auto", verbose = 1, patience = 15)

# %%
model.fit(x = X_train, y = y_train, validation_data = (X_test, y_test), batch_size = 64, epochs = 1000, verbose = 1,
          callbacks = [early_stop])
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6812 - accuracy: 0.5684 - val_loss: 0.6703 - val_accuracy: 0.7368
# Epoch 2/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6619 - accuracy: 0.8223 - val_loss: 0.6515 - val_accuracy: 0.8246
# Epoch 3/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6442 - accuracy: 0.8262 - val_loss: 0.6314 - val_accuracy: 0.8070
# Epoch 4/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6234 - accuracy: 0.8301 - val_loss: 0.6089 - val_accuracy: 0.7544
# Epoch 5/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5985 - accuracy: 0.8457 - val_loss: 0.5825 - val_accuracy: 0.8947
# Epoch 6/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5710 - accuracy: 0.8770 - val_loss: 0.5548 - val_accuracy: 0.9123
# Epoch 7/1000
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
#y_pred = model.predict_classes(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[20  1]
#  [ 2 34]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        21
#            1       0.97      0.94      0.96        36
#
#     accuracy                           0.95        57
#    macro avg       0.94      0.95      0.94        57
# weighted avg       0.95      0.95      0.95        57

# %%
model.save('model_cancer.h5')

# %% [markdown]
# ## Loading Model and Scaler

# %% [raw]
# Diyelim başka bir yere, başka bir bilgisayara geçtim. orada import ve load ederek modelimi yeni değerlerle çalıştıracağım.

# %%
from tensorflow.keras.models import load_model

# %%
model_cancer = load_model('model_cancer.h5')
scaler_cancer = pickle.load(open("scaler_cancer", "rb"))

# %% [markdown]
# ## Prediction

# %%
single_patient = df.drop('Cancer', axis = 1).iloc[0:1, :]
single_patient
# Out:
#    mean radius  mean texture  mean smoothness  mean compactness  \
# 0       17.990        10.380            0.118             0.278
#
#    mean concavity  mean concave points  mean symmetry  mean fractal dimension  \
# 0           0.300                0.147          0.242                   0.079
#
#    radius error  texture error  ...  symmetry error  fractal dimension error  \
# 0         1.095          0.905  ...           0.030                    0.006
#
#    worst radius  worst texture  worst smoothness  worst compactness  \
# 0        25.380         17.330             0.162              0.666
#
#    worst concavity  worst concave points  worst symmetry  \
# 0            0.712                 0.265           0.460
#
#    worst fractal dimension
# 0                    0.119
#
# [1 rows x 24 columns]

# %%
single_patient = scaler_cancer.transform(single_patient)
single_patient
# Out:
# array([[1.799e+01, 1.038e+01, 1.184e-01, 2.776e-01, 3.001e-01, 1.471e-01,
#         2.419e-01, 7.871e-02, 1.095e+00, 9.053e-01, 6.399e-03, 4.904e-02,
#         5.373e-02, 1.587e-02, 3.003e-02, 6.193e-03, 2.538e+01, 1.733e+01,
#         1.622e-01, 6.656e-01, 7.119e-01, 2.654e-01, 4.601e-01, 1.189e-01]])

# %%
(model_cancer.predict(single_patient) > 0.5).astype("int32")

# değer 0.5 ten büyükse 1 küçükse 0 verecek. (kanser veya değil..)
# Out:
# array([[0]])

# %%
df["Cancer"].iloc[0]
# Out:
# 0

# %% [markdown]
# ## Comparison with ML

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression()
log_model.fit(X_train, y_train)
y_pred = log_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[20  1]
#  [ 1 35]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        21
#            1       0.97      0.97      0.97        36
#
#     accuracy                           0.96        57
#    macro avg       0.96      0.96      0.96        57
# weighted avg       0.96      0.96      0.96        57

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[20  1]
#  [ 1 35]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        21
#            1       0.97      0.97      0.97        36
#
#     accuracy                           0.96        57
#    macro avg       0.96      0.96      0.96        57
# weighted avg       0.96      0.96      0.96        57

# %% [raw]
# Logistic Reg. ve Random Forest ile güzel sonuçlar aldık. zaten bu data Machine LEarning için uygun derecede küçük basit data.
# Deep Learning i çok daha büyük, kompleks ve öğrenme tekrarı gerektiren datalarda kullanıyoruz.
