# %%
# Visualization

# %%
import matplotlib.pyplot as plt

plt.plot(x, y)

plt.plot(x, y);

plt.show()

plt.title('String Title');

plt.xlabel('X Axis')

plt.ylabel('Y Axis')

plt.xlim(0,6)

plt.ylim(0,15)

plt.yscale("log")

plt.xticks(rotation=15)

plt.tight_layout()

plt.show()

plt.grid(which='both',axis='y')

plt.savefig('myfirstplot.png') # to python dir.

plt.figure()

plt.figure(figsize=(10,10))

fig = plt.figure(figsize=(4,10), dpi = 200)

fig = plt.figure(nrows=2, ncols=2, figsize=(4,10), dpi = 200)

axes1 = fig.add_axes([0,0,1,1])

axes1.plot(a,b)

axes.plot(x, y)

axes1.set_xlim(0, 8)

axes1.set_ylim(0, 8000)

axes1.set_xlabel('A')

axes1.set_ylabel('B')

axes1.set_title('Power of 4')

fig.suptitle('Figure Level', fontsize=16)

fig.savefig('new_figure.png')

fig.savefig('new_figure.png', bbox_inches = "tight")

plt.tight_layout()   
    
fig.subplots_adjust(wspace=1, hspace=1) 

fig.set_figwidth(10)

fig, axes = plt.subplots()

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,6))
axes[0].plot(x,y)
axes[1].plot(a,b)

fig, axes = plt.subplots(nrows=2, ncols=2)
axes[0][0].plot(x,y)
axes[0][1].plot(a,b)
axes[1][0].plot(c,v)
axes[1][1].plot(e,f)

axes.shape

type(fig)

fig, axes = plt.subplots(nrows=3, ncols=1)
for ax in axes : 
    ax.plot(x,,y)

ax.plot(x,y, label = 'x vs y' )    
        
ax.legend()
    
ax.legend(loc='lower left')    
    
ax.legend(loc=(1.1, 0.5))    
    
ax.plot(x, x, color = 'lightblue')    
    
ax.plot(x, x, color = '#e6c017')

ax.plot(x, x, linewidth = 10)  #  also "lw" instead of linewidth

ax.plot(x, x, linesize = '--', label = 'x vs x' )  # also "ls" instead of linesize

lines = ax.plot(x, x+1, color = 'purple', linewidth=5)
lines[0].set_dashes([1,1,1,2,3,5]) # çizginin her bir elemanını özelleştirme (nokta+boşluk)

ax.plot(x, x+1, marker='o')

ax.plot(x, x+1, color = 'purple', linewidth=2, marker='+', ls = '--', markersize=20) # also "ms" instead of markersize

ax.plot(x, x, color = 'purple', linewidth=2, marker='o', ls = '--', ms=10,
       markerfacecolor='red', markeredgewidth=8, markeredgecolor='orange')

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(4,10), dpi = 200)

axes[0][0].plot(x,y)

axes[0][1].plot(x,y)

axes[1][0].plot(x,y)
axes[1][0].set_ylabel('Y label')
axes[1][0].set_xlim(2,6)
axes[1][0].set_ylim(0, 100)

axes[1][1].plot(a,b)
axes[1][1].set_title('TITLE 1,1')

fig.suptitle('Figure Level', fontsize=16)

plt.tight_layout

fig.savefig('new_subplots.png', bbox_inches='tight')

# %% [markdown]
# ### Seaborn visualization

# %%
http://seaborn.pydata.org/

import seaborn as sns

# Scatter Plot

data

hue

size
s

alpha

style

sns.scatterplot(x= 'salary', y='sales', data=df, size='salary', hue='level of education',
               palette='Dark2', s=200, alpha=0)

sns.scatterplot(x= 'salary', y='sales', data=df, s=200, style='level of education')

fig, ax= plt.subplots(1,2,figsize=(10,5))
sns.scatterplot(data=tips, x='total_bill',y='tip', s=300, hue='sex', ax=ax[0])
sns.histplot(data=mpg, x='weight', ax=ax[1]);

# Distribution Plots

    # rugplot
    
sns.rugplot(x='salary', data=df, height = 0.5)

plt.figure(figsize=(5,8), dpi = 100)   # dpi veya figsize girmeyeceksen buna ihtiyaç yok
sns.rugplot(x='salary', data=df, height = 0.5)

    # displot

sns.displot(data=df, x='salary', kind="kde")  # kind = "hist" --> default

sns.displot(data=df, x='salary', kde=True, aspect=1.5)

sns.displot(data=df, x='salary', bins=20, color='red', edgecolor='blue', linewidth=4, linestyle='--')

sns.displot(data=df, x='salary', kde=True, rug=True)


    # sns.distplot  (DIS T PLOT !!!!)
    
sns.distplot(mpg.horsepower)

    # histplot
    
sns.histplot(data=df, x='salary')

sns.histplot(data=mpg, x='weight', kde= True);


#sns.kdeplot()

sns.kdeplot(data=df, x='salary')

sns.kdeplot(data=penguins, x="bill_length_mm", hue="sex", shade = True);

sns.kdeplot(data=tips, x="total_bill", y="tip", color="red", shade = True);

# sns.set(style="   ")
sns.set(style='darkgrid')  # also style can be = whitegrid, dark, white, ticks

markers={"Male": ">", "Female": "<"}
sns.scatterplot(data=tips, x='total_bill',y="tip", style='sex', hue="sex", s= 150, markers=markers);

        # EXAMPLES:

np.random.seed(42)
sample_ages = np.random.randint(0, 100, 200 )
sample_ages = pd.DataFrame(sample_ages, columns = ['age'])
sns.rugplot(data=sample_ages, x='age')
sns.displot(data=sample_ages, x='age', rug=True, bins=30) 
sns.displot(data=sample_ages, x='age', rug=True, bins=30, kde=True) 
sns.kdeplot(data=sample_ages, x='age')
sns.kdeplot(data=sample_ages, x='age', clip = [0,100])
sns.kdeplot(data=sample_ages, x='age', clip = [0,100], bw_adjust=0.01)
