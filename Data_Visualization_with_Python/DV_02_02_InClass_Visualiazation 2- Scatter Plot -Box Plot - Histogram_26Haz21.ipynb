# %% [markdown]
# # ÖNCEKİ DERSİN ÖZETİ

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


# %matplotlib inline

# %% [raw]
# pip install jupyter_contrib_nbextensions
# jupyter contrib nbextension install --user

# %% [raw]
# pip3 install jupyter-tabnine --user
# jupyter nbextension install --py jupyter_tabnine --user
# jupyter nbextension enable --py jupyter_tabnine --user
# jupyter serverextension enable --py jupyter_tabnine --user

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary = [38496, 42000, 46752, 49320, 53200,
         56000, 62316, 64928, 67317, 68748, 73752]
salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]

# %%
# functional olarak (fonksiyon çağırarak. fonksiyonun içine değişkeni/değişkenleri yazarak)

plt.plot(salary)

# %%
# functional

plt.plot(age, salary)

# şimdi age değişkenleri ile birleşti.

# %%
# iki çizgi çıksın istersem:
# ikinci çizgi için farklı bir değişken (salary_2) kullanarak y eksinini kaydırıyorum

plt.plot(age, salary)
plt.plot(age, salary_2)ikinci plotta y eksinine farklı değer girdiğim için ikinci çizgiyi çizgi

# %%
# legend kullanırsak:
# legend'de label ları ya plt.plot() fonksiyonunun içinde tanımlıyoruz.
 
plt.plot(age, salary, label="1")
plt.plot(age, salary_2, label="2")
plt.legend()

# %%
# veya legend() fonksiyonunun içinde de tanımlayabiliriz.
 
plt.plot(age, salary)
plt.plot(age, salary_2)
plt.legend(["1", "2"])

# %%
plt.plot(age, salary, age, salary_2) 

plt.legend(["1", "2"])

# iki farklı axes'ı (age-salary ve age-salary_2) sırayla fonksiyon içine soktum. iki çizgili şekil elde ettim.

# %%
# fonksiyonda 2 axes kullandığımda legend'in label'larını fonksiyon içinde değil, legend() fonksiyonunun içinde tanımlıyorum!!!

plt.plot(age, salary, age, salary_2)
plt.legend(["1", "2"])

# %%
# object oriented olarak:

# önce object'leri oluşturuyoruz ( tanımlıyoruz )

# sonra .plot metodu ile verilerimi giriyoruz

fig, ax = plt.subplots()
ax.plot(age, salary)

# object oriented metotda --> plt.subplots

# %%
plt.subplot(1,2,1)
plt.plot(age, salary)

# function metotda --> plt.subplot

# %% [raw]
# fonksiyonda               --> subplot   (s yok)
# object oriented metod ile --> subplots  (s var)
#
# plt.subplot(1,2,1)
#
# fig, ax = plt.subplots()

# %%
plt.subplot(1,2,1)
plt.plot(age, salary)

plt.subplot(1,2,2)
plt.plot(age, salary_2)

# iki ayrı axes çizdik. ama iç içe geçti. bunu düzeltelim.

# %%
# 1. figure size ını genişleterek düzeltebiliriz.

plt.figure(figsize=(16,4))

plt.subplot(1,2,1)
plt.plot(age, salary)

plt.subplot(1,2,2)
plt.plot(age, salary_2)

# %%
# 2. plt.tight_layout() ile düzelttik.

plt.subplot(1,2,1)
plt.plot(age, salary)

plt.subplot(1,2,2)
plt.plot(age, salary_2)

plt.tight_layout()

# %%
fig, ax1 = plt.subplots(nrows=1, ncols=2)  # nrows = 1, ncols=2 yerine positional olarak 1,2 şeklinde de yazabiliriz.
ax1[0].plot(age, salary)
ax1[1].plot(age, salary_2)
plt.tight_layout()

# %%
fig, ax1 = plt.subplots(nrows=2, ncols=2)
ax1[0,0].plot(age, salary)  # age-salary'i 0-0 indekse çizdi
ax1[0,1].plot(age, salary_2) # age-salary_2'yi 0-1 indekse çizdi
plt.tight_layout()  

# geri kalan 2 indeks için veri tanımlanmadığı için boş olarak çizdi

# %%
fig, ax1 = plt.subplots(2,2)
ax1[0,0].plot(age, salary)
ax1[1,0].plot(age, salary_2)

ax1[1,1].plot(salary, age)
ax1[0,1].text(0.2, 0.5, 'Aziz hocama saygılar', style ='italic', fontsize = 10, color ="green")
plt.tight_layout()

# %%
def multi_graf(rows, cols):
    fig, ax = plt.subplots(nrows=rows, ncols=cols)
    for i in range(rows):
        for j in range(cols):
            ax[i,j].plot(age, salary)
    plt.tight_layout()
multi_graf(2,2)

# %%
def multi_graf(rows, cols):
    fig, ax = plt.subplots(nrows=rows, ncols=cols)
    for i in range(rows):
        for j in range(cols):
            ax[i,j].plot(age, salary)
    plt.tight_layout()
multi_graf(2,3)

# %%
for i in range(1, 7):  # fonksiyonel metod ile 0'dan başlamıyorduk. 1'den başlıyoruz.
    plt.subplot(2,3,i)
    
plt.tight_layout()

# %%
# bunlara title ekleyelim:

for i in range(1, 7):  # fonksiyonel metod ile 0'dan başlamıyorduk. 1'den başlıyoruz.
    plt.subplot(2,3,i)
    plt.title(i)
plt.tight_layout()

# %%
# şimdi de plotların içine age ve salary verilerini gönderelim çizgileri de görelim.

for i in range(1,7):
    plt.subplot(2,3,i)
    plt.plot(age, salary)
    plt.title(i)
plt.tight_layout()

# %% [markdown]
# # SCATTER PLOT

# %% [markdown]
# ## Scatter plot iki SAYISAL değişkenin arasındaki ilişkiyi gösterir.

# %%
x= np.array([15,17,18,17,12,17,12,19,14,11,12,19,16,13])
y= np.array([99,86,87,88,81,86,93,87,94,78,77,85,86,85])
plt.scatter(x, y)
plt.show()

# x ile y'nin her bir değerini birbirleri ile eşleştiriyor ve oraya nokta koyuyor.

# %%
import seaborn as sns

# %%
sns.get_dataset_names
# Out:
# <function seaborn.utils.get_dataset_names()>

# %%
tips = sns.load_dataset("tips")

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Ben bu data setimde scatter plot çalıştırmam gerekirse hangi iki sütunu çalıştırmalıyım?

# %%
# tip ve total_bill i alırım.

# %%
plt.scatter(tips.tip, tips.total_bill)

# noktaların yoğun olduğu yerlerden sol alttan sağ üste doğru bir çizgi çizersek, alt fiyatlarda yaklaşık yüzde 20'ye yakın bahşiş verildiği fakat ödenen fiyat yükseldikçe bahşiş oranının düştüğü gözüküyor
# fakat genel anlamda yüzde 20'ye yakın bahşişten bahsedebiliriz.

# %% [markdown]
# # Nominal & Ordinal

# %% [raw]
# Sınıflama Ölçeği (Nominal): Sınıflama ölçeğinde değişkenlerin aldığı değerler sayısal bir büyüklük ifade etmezler. ... Sıralama Ölçeği (Ordinal): Sınıflama ölçeğinde değişkenlerin aldığı değerler önem derecesi ya da üstünlükleri baz alınarak sıralanır.

# %%
x = np.array(["A","B","C","D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
plt.show

# Bu verinin ORDİNAL VEYA NOMİNAL olup olmaması, A - D değerlerinin neleri ifade ettigine göre değişir
# Açıklarken A düşük seviye D yüksek seviye olarak tanımlanırsa Ordinal olur.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# inClass'ya hangi programlama dilini biliyorsunuz sorusuna verilen cevaplardan grafik oluşturduk. 

# C :1, C++ :3 olduğu için ve bu diller benzer olduğu için bunları C altında birleştirdik.

fig, ax = plt.subplots()
langs = ['C', 'Python', 'PHP', "HTML&Css", "sql", "git&linux"]
students = [3,25,1,14,22,18]
ax.bar(langs,students)
plt.show()
# Out:
# (None,)

# %%
fig, ax = plt.subplots()
langs = ['C', 'Python', 'PHP', "HTML&Css", "sql", "git&linux"]
students = [3,25,1,14,22,18]
ax.barh(langs,students)
plt.show()
# Out:
# (None,)

# %%
day = tips.day.unique()
day

# bunu birazdan plotlamada kullanacağız.
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %%
tips["day"].value_counts()

# yukardaki cell de günleri gün sayısına göre sıralamış.
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
# sunday'de kaç total_bill var? pandası kullanıp groupby kullanacağız. 

total_bill = tips.groupby("day")["total_bill"].sum()

total_bill

# bunu da plotlamada kullanacağız.
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64

# %%
# şimdi bunu bar plotun içine atalım ve şekli görelim.

# %%
day = tips.day.unique()
total_bill = tips.groupby("day")["total_bill"].sum()

fig, ax = plt.subplots()
ax.bar(day, total_bill)
# ax.set_xticks(ind+width/2)    # bu ve alttaki satır barların üzerine kümülatif toplamını yazdırmak için.
# ax.set_xticklabels(x, minor=False)  # fakat çalışmadı. bu konuya bakılacak!!

plt.show()

# day'i belirlerken unique dediğimi için gün sıralaması yanlış oldu.

# %%
# gün gruplaması yaparak day-total_bill plotuna bakalım

day = tips.groupby("day").sum().index   # day olarak gruplandırılmış dataframe'in index'ini aldım yani sırayla günleri çekmiş oldum.
total_bill = tips.groupby("day")["total_bill"].sum()
fig, ax = plt.subplots()
ax.bar(day,total_bill)
plt.show()

# %%
# gün gruplaması yaparak day-tip plotuna bakalım

day = tips.groupby("day").sum().index   # day olarak gruplandırılmış dataframe'in index'ini aldım yani sırayla günleri çekmiş oldum.
tip = tips.groupby("day")["tip"].sum()
fig, ax = plt.subplots()
ax.bar(day,tip)
plt.show()

# %%
# cinsiyet gruplaması yaparak sex-tips plotuna bakalım

sex = tips.groupby("sex").sum().index
tip = tips.groupby("sex")["tip"].sum()
fig, ax = plt.subplots()
ax.bar(sex,tip)
plt.show()

# %%
# iki axes'i birden görüntülesin istiyorum:

day = tips.groupby("day").sum().index
tip = tips.groupby("day")["tip"].sum()
total = tips.groupby("day")["total_bill"].sum()
fig, ax = plt.subplots()
ax.bar(day, total, label="total" )
ax.bar(day, tip, label="tip" )
plt.legend()
plt.show()

# %%
# tip sütunlarını daraltınca total ondan geniş kalacağı için daha güzel bir görünüm ortaya çıktı.

day = tips.groupby("day").sum().index
tip = tips.groupby("day")["tip"].sum()
total = tips.groupby("day")["total_bill"].sum()
fig, ax = plt.subplots()
ax.bar(day, tip, label="tip", align="edge")
ax.bar(day, total, label="total",width=0.6, align="edge")
plt.legend()
plt.show()

# %% [markdown]
# ## Histogram

# %% [raw]
# Bar grafiğinde sütunlar ayrık, histogramda yan yana bitişik.

# %%
# rastgele sayılar üreterek tanımladığım x değişkeninin histogramına bakalım:

x = np.random.normal(170,10,250)
plt.hist(x, bins=50)
plt.show()

# %%
# tips datasetimizin total_bill sütununun histogramına bakalım.

plt.hist(tips.total_bill)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# biraz bins verelim. çubuk sayısını arttıralım ki veriler daha net gözüksün

plt.hist(tips.total_bill, bins = 50)
plt.show()

# %%
tips.total_bill.mean()
# Out:
# 19.78594262295082

# %%
tips.total_bill.median()
# Out:
# 17.795

# %%
# bir de tips datasetimizin tip sütununun histogramına bakalım.

plt.hist(tips.tip, bins=50)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Box Plot

# %% [raw]
# a box plot is a method for graphically depicting groups of numerical data through their quartiles.
#
# box plot, sayısal veri gruplarını çeyreklerine göre grafiksel olarak gösteren bir yöntemdir.
#
# a box plot generally shows median, 25th and 75th percentiles, and outliers.
#
# bir box plot genellikle medyanı, 25. ve 75. yüzdelikleri ve outlier'ları gösterir.

# %% [raw]
# box plot bize en fazla istatistiksel bilgi veren plottur.

# %%
# az önceki x değişkenine tanımladığım datamın box plotunu görelim:

x = np.random.normal(170,10,250)
plt.boxplot(x)
plt.show()

# %%
# birden fazla box plotu görmek istersem:

box = np.array(np.random.rand(10,4))
plt.boxplot(box, labels = ["A", "B", "C", "D"])  
plt.show()

# box, her defasında random olarak farklı değerler üretecektir. her harfi temsil eden boxplotlar farklı değerlere sahip olacaktır.

# %%
box = np.array(np.random.rand(10,4))
plt.boxplot(box, labels=["a","b","c","d"], vert= False)
plt.show()

# vert=False yaptım. horizontal oldu.

# %%
# tips datasetimdeki total_bill sütununun boxplotunu görelim:

plt.figure(figsize=(16,6))
plt.boxplot(tips.total_bill, vert=False)
plt.show()

# %%
plt.boxplot([tips["total_bill"],tips["tip"]], labels=["A","B"], vert= False)
plt.show()

# total_bill ve tip sütunlarının
