# %%
import numpy as np
import pandas as pd

# %%
df_2021 = pd.read_csv('world-happiness-report-2021.csv')

# %%
df_history = pd.read_csv('world-happiness-report.csv')

# %%
df_2021.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df_history.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
df1_2021 = df_2021[['Country name', 'Regional indicator', 'Ladder score',
       'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']].copy()

# df1_2021 sütunlarını (isimleri birebir aynı olmasa da) df_history ile eşitledik ve bunu yeni bir tabloya bu halini eşitledik.

# %%
df_history.head(1)
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724                7.37           0.451
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.8                         0.718       0.168
#
#    Perceptions of corruption  Positive affect  Negative affect
# 0                      0.882            0.518            0.258

# %%
history_df = df_history[['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
       'Social support', 'Healthy life expectancy at birth',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']].copy()

# positive affect ve negative affect sütunları işimize yaramadığı için onları düşürdük yeni bir tabloya bu halini eşitledik.

# %%
history_df.head(1)
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724                7.37           0.451
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.8                         0.718       0.168
#
#    Perceptions of corruption
# 0                      0.882

# %%
df1_2021.rename(columns = {'Ladder score':'Life Ladder', 'Logged GDP per capita':'Log GDP per capita', 'Healthy life expectancy': 'Healthy life expectancy at birth', }, inplace=True)

# %%
df1_2021.head(1)

# year sütunu yoktu. aşağıdaki line ı önce çalıştırdığım için burda gözüküyor. normalde yok.
# Out:
#   Country name Regional indicator  Life Ladder  Log GDP per capita  \
# 0      Finland     Western Europe        7.842              10.775
#
#    Social support  Healthy life expectancy at birth  \
# 0           0.954                              72.0
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.949      -0.098                      0.186

# %%
df1_2021['year'] = 2021

# history ile eşit olsun diye year sütununu da ekledik ve içine 2021 değerini atadık.

# %%
df1_2021.head(1)
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe         7.842                 10.775
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
#
#    Generosity  Perceptions of corruption  year
# 0      -0.098                      0.186  2021

# %%
df1_2021['Regional indicator'].value_counts()

# Önce Regional indicatorları görelim. bu sütun df1_2021 deydi. daha sonra bunu history'e ekleyeceğiz
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Middle East and North Africa          17
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: Regional indicator, dtype: int64

# %%
df_north = df1_2021[df1_2021["Regional indicator"] == "North America and ANZ"]
df_north
# Out:
#      Country name     Regional indicator  Life Ladder  Log GDP per capita  \
# 8     New Zealand  North America and ANZ        7.277              10.643
# 10      Australia  North America and ANZ        7.183              10.796
# 13         Canada  North America and ANZ        7.103              10.776
# 18  United States  North America and ANZ        6.951              11.023
#
#     Social support  Healthy life expectancy at birth  \
# 8            0.948                              73.4
# 10           0.940                              73.9
# 13           0.926                              73.8
# 18           0.920                              68.2
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  year
# 8                          0.929       0.134                      0.242  2021
# 10                         0.914       0.159                      0.442  2021
# 13                         0.915       0.089                      0.415  2021
# ...

# %%
df_north["Country name"].to_list()

# df_north datasetindeki ülkeleri listeye aldık. sonra bu listeleri df_history datasetinde 
# region indicatorları belirlerken kullanacağız                                                                                                                                                                                                                                                                                           Regional indicator sütununu oluştururken
# Out:
# ['New Zealand', 'Australia', 'Canada', 'United States']

# %%
western = df1_2021[df1_2021['Regional indicator'] == 'Western Europe']
western
# Out:
#       Country name Regional indicator  Life Ladder  Log GDP per capita  \
# 0          Finland     Western Europe        7.842              10.775
# 1          Denmark     Western Europe        7.620              10.933
# 2      Switzerland     Western Europe        7.571              11.117
# 3          Iceland     Western Europe        7.554              10.878
# 4      Netherlands     Western Europe        7.464              10.932
# 5           Norway     Western Europe        7.392              11.053
# 6           Sweden     Western Europe        7.363              10.867
# 7       Luxembourg     Western Europe        7.324              11.647
# 9          Austria     Western Europe        7.268              10.906
# 12         Germany     Western Europe        7.155              10.873
# 14         Ireland     Western Europe        7.085              11.342
# 16  United Kingdom     Western Europe        7.064              10.707
# ...

# %%
western["Country name"].to_list()

# bunun gibi diğer tüm bölgelerdeki ülkeleri de bulacağız.
# Out:
# ['Finland',
#  'Denmark',
#  'Switzerland',
#  'Iceland',
#  'Netherlands',
#  'Norway',
#  'Sweden',
#  'Luxembourg',
#  'Austria',
#  'Germany',
#  'Ireland',
#  'United Kingdom',
#  'Belgium',
#  'France',
#  'Malta',
#  'Spain',
#  'Italy',
#  'Cyprus',
#  'Portugal',
#  'Greece',
#  'North Cyprus']

# %%
df_north = df1_2021[df1_2021['Regional indicator'] == 'North America and ANZ']
df_north['Country name']

# alttaki fonksiyonu oluşturmak için bilgileri nerden aldığımızı çalıştık.
# Out:
# 8       New Zealand
# 10        Australia
# 13           Canada
# 18    United States
# Name: Country name, dtype: object

# %%
df_north['Country name'].to_list()

# aşağıdaki listeyi şimdi alıp fonksiyonda yerine koyabiliriz.
# bunun yerine yukardan kopyala yapıştır da yapabilirdik kolaylık olsun diye to_list() metodu kullandık.
# Out:
# ['New Zealand', 'Australia', 'Canada', 'United States']

# %%
def region(country):
    if country in ['Mauritius','Congo (Brazzaville)','Ivory Coast','Cameroon','Senegal','Ghana','Niger','Gambia','Benin','Guinea','South Africa','Gabon','Burkina Faso','Mozambique','Nigeria','Mali','Uganda','Liberia','Kenya','Namibia','Chad','Swaziland','Comoros','Ethiopia','Mauritania','Madagascar','Togo','Zambia', 'Sierra Leone','Burundi','Tanzania','Malawi','Lesotho','Botswana','Rwanda','Zimbabwe']:
        return 'Sub-Saharan Africa'
    elif country in ['Finland','Denmark','Switzerland','Iceland','Netherlands','Norway','Sweden','Luxembourg','Austria','Germany','Ireland','United Kingdom','Belgium','France','Malta','Spain','Italy','Cyprus','Portugal','Greece','North Cyprus']:
        return 'Western Europe'
    elif country in ['Costa Rica','Guatemala','Uruguay','Brazil','Mexico','Jamaica','Panama','Chile','El Salvador','Colombia','Nicaragua','Argentina','Honduras','Peru','Ecuador','Bolivia','Paraguay','Dominican Republic','Venezuela','Haiti']:
        return 'Latin America and Caribbean'
    elif country in ['Israel','Bahrain','United Arab Emirates','Saudi Arabia','Kuwait','Libya','Turkey','Morocco','Algeria','Iraq','Iran','Tunisia','Lebanon','Palestinian Territories','Jordan','Egypt','Yemen']:
        return 'Middle East and North Africa'
    elif country in ['Czech Republic','Slovenia','Kosovo','Slovakia','Lithuania','Estonia','Poland','Romania','Serbia','Latvia','Hungary','Croatia','Bosnia and Herzegovina','Montenegro', 'Bulgaria','Albania','North Macedonia']:
        return 'Central and Eastern Europe'
    elif country in ['Uzbekistan','Kazakhstan','Moldova','Kyrgyzstan','Belarus','Russia','Tajikistan','Armenia','Azerbaijan','Turkmenistan','Georgia','Ukraine']:
        return 'Commonwealth of Independent States'
    elif country in ['Singapore','Thailand','Philippines','Vietnam','Malaysia','Indonesia','Laos','Cambodia','Myanmar']:
        return 'Southeast Asia'
    elif country in ['Nepal','Maldives','Bangladesh','Pakistan','Sri Lanka','India','Afghanistan']:
        return 'South Asia'
    elif country in ['Taiwan Province of China','Japan','South Korea','Mongolia','Hong Kong S.A.R. of China','China']:
        return 'East Asia'
    elif country in ['New Zealand', 'Australia', 'Canada', 'United States']:
        return 'North America and ANZ'

# %%
history_df['Regional indicator'] = history_df['Country name'].apply(region)

history_df

# Regional indicator sütunu oluşturup buna history_df'in country name lerini region fonksiyonuna uygulayarak burdan return olan 
# regionları ona atadık. (fonksiyondaki country parametresine country name değerleri giriyor ve region return oluyor.)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
# şimdi df_2021 üzerinde çalışıyoruz. sonra df_2021 i df_history'e ekleyeceğiz

df_sub_saharan = df1_2021[df1_2021["Regional indicator"]=="Sub-Saharan Africa"]
df_sub_saharan

# bunun gibi diğer tüm regionları da yapıyoruz
# Out:
#             Country name  Regional indicator  Life Ladder  Log GDP per capita  \
# 49             Mauritius  Sub-Saharan Africa        6.049              10.008
# 82   Congo (Brazzaville)  Sub-Saharan Africa        5.342               8.117
# 84           Ivory Coast  Sub-Saharan Africa        5.306               8.551
# 90              Cameroon  Sub-Saharan Africa        5.142               8.189
# 91               Senegal  Sub-Saharan Africa        5.132               8.118
# 94                 Ghana  Sub-Saharan Africa        5.088               8.580
# 95                 Niger  Sub-Saharan Africa        5.074               7.098
# 97                Gambia  Sub-Saharan Africa        5.051               7.686
# 98                 Benin  Sub-Saharan Africa        5.045               8.087
# 101               Guinea  Sub-Saharan Africa        4.984               7.838
# 102         South Africa  Sub-Saharan Africa        4.956               9.403
# ...

# %%
df_north = df1_2021[df_2021["Regional indicator"] == 'North America and ANZ']
df_north

# diğer bölgeleri de aynı komutla değişkenlere atıyoruz.
# Out:
#      Country name     Regional indicator  Life Ladder  Log GDP per capita  \
# 8     New Zealand  North America and ANZ        7.277              10.643
# 10      Australia  North America and ANZ        7.183              10.796
# 13         Canada  North America and ANZ        7.103              10.776
# 18  United States  North America and ANZ        6.951              11.023
#
#     Social support  Healthy life expectancy at birth  \
# 8            0.948                              73.4
# 10           0.940                              73.9
# 13           0.926                              73.8
# 18           0.920                              68.2
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  year
# 8                          0.929       0.134                      0.242  2021
# 10                         0.914       0.159                      0.442  2021
# 13                         0.915       0.089                      0.415  2021
# ...

# %%
df_sub_saharan = df1_2021[df1_2021["Regional indicator"] == "Sub-Saharan Africa"]

# %%
df_west = df1_2021[df1_2021["Regional indicator"] == "Western Europe"]

# %%
df_latin=df1_2021[df1_2021['Regional indicator']=='Latin America and Caribbean']

# %%
df_middle_east=df1_2021[df1_2021['Regional indicator']=='Middle East and North Africa']

# %%
df_central=df1_2021[df1_2021['Regional indicator']=='Central and Eastern Europe']

# %%
df_commonwealth=df1_2021[df1_2021['Regional indicator']=='Commonwealth of Independent States']

# %%
df_Southeast=df1_2021[df1_2021['Regional indicator']=='Southeast Asia']

# %%
df_South=df1_2021[df1_2021['Regional indicator']=='South Asia']

# %%
df_East=df1_2021[df1_2021['Regional indicator']=='East Asia']

# %%
df_north = df1_2021[df1_2021['Regional indicator']=='North America and ANZ']

# %%
# şimdi append yöntemi ile Türkiye satırını diğer datasetine ekleyeceğiz.

# %%
history_df = history_df.append([df_sub_saharan,df_west,df_latin,df_middle_east,df_central,df_commonwealth,df_Southeast,df_South,df_East,df_north],ignore_index = True)

# yukarda tanımladığımız tüm regionlarıhistory_df'e appende yapıp bunu kendisine eşitledik ki kalıcı olsun.

# %% [markdown]
# # 2. soru cevabı:

# %%
history_df[history_df["Regional indicator"] == "Sub-Saharan Africa"].groupby("Country name")[["Life Ladder", "Freedom to make life choices", "Perceptions of corruption"]].describe()

# Regional indicator'ı Sub-sahatran africa olanları "country name" lere göre grupla 
# ve sağda belirtilen sütunların ("Life Ladder", "Freedom to make life choices", "Perceptions of corruption")
# describe bilgilerini göster.
# Out:
#                     Life Ladder                                                \
#                           count   mean std    min    25%    50%    75%    max
# Country name
# Benin                       1.0  5.045 NaN  5.045  5.045  5.045  5.045  5.045
# Botswana                    1.0  3.467 NaN  3.467  3.467  3.467  3.467  3.467
# Burkina Faso                1.0  4.834 NaN  4.834  4.834  4.834  4.834  4.834
# Burundi                     1.0  3.775 NaN  3.775  3.775  3.775  3.775  3.775
# Cameroon                    1.0  5.142 NaN  5.142  5.142  5.142  5.142  5.142
# Chad                        1.0  4.355 NaN  4.355  4.355  4.355  4.355  4.355
# Comoros                     1.0  4.289 NaN  4.289  4.289  4.289  4.289  4.289
# Congo (Brazzaville)         1.0  5.342 NaN  5.342  5.342  5.342  5.342  5.342
# Ethiopia                    1.0  4.275 NaN  4.275  4.275  4.275  4.275  4.275
# Gabon                       1.0  4.852 NaN  4.852  4.852  4.852  4.852  4.852
# ...

# %%
history_df[history_df["Regional indicator"] == "South Asia"].groupby("Country name")[["Life Ladder", "Freedom to make life choices", "Perceptions of corruption"]].describe()
# Out:
#              Life Ladder                                                \
#                    count   mean std    min    25%    50%    75%    max
# Country name
# Afghanistan          1.0  2.523 NaN  2.523  2.523  2.523  2.523  2.523
# Bangladesh           1.0  5.025 NaN  5.025  5.025  5.025  5.025  5.025
# India                1.0  3.819 NaN  3.819  3.819  3.819  3.819  3.819
# Maldives             1.0  5.198 NaN  5.198  5.198  5.198  5.198  5.198
# Nepal                1.0  5.269 NaN  5.269  5.269  5.269  5.269  5.269
# Pakistan             1.0  4.934 NaN  4.934  4.934  4.934  4.934  4.934
# Sri Lanka            1.0  4.325 NaN  4.325  4.325  4.325  4.325  4.325
#
#              Freedom to make life choices         ...                \
#                                     count   mean  ...    75%    max
# Country name                                      ...
# Afghanistan                           1.0  0.382  ...  0.382  0.382
# ...

# %% [markdown]
# # 4.soru cevabı

# %%
history_df[history_df["Country name"]=="India"]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 732         India  2006        5.348               8.145           0.707
# 733         India  2007        5.027               8.204           0.569
# 734         India  2008        5.146               8.220           0.684
# 735         India  2009        4.522               8.281           0.653
# 736         India  2010        4.989               8.349           0.605
# 737         India  2011        4.635               8.387           0.553
# 738         India  2012        4.720               8.428           0.511
# 739         India  2013        4.428               8.478           0.553
# 740         India  2014        4.424               8.538           0.621
# 741         India  2015        4.342               8.604           0.610
# 742         India  2016        4.179               8.673           0.614
# 743         India  2017        4.046               8.730           0.607
# ...

# %%
history_df[history_df["Country name"]=="Zimbabwe"]

# istenen diğer ülkelerin bilgilerini de aynı şekilde getir.
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1934     Zimbabwe  2006        3.826               7.711           0.822
# 1935     Zimbabwe  2007        3.280               7.666           0.828
# 1936     Zimbabwe  2008        3.174               7.461           0.843
# 1937     Zimbabwe  2009        4.056               7.563           0.806
# 1938     Zimbabwe  2010        4.682               7.729           0.857
# 1939     Zimbabwe  2011        4.846               7.846           0.865
# 1940     Zimbabwe  2012        4.955               7.983           0.896
# 1941     Zimbabwe  2013        4.690               7.985           0.799
# 1942     Zimbabwe  2014        4.184               7.991           0.766
# 1943     Zimbabwe  2015        3.703               7.992           0.736
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# ...

# %% [markdown]
# # 5.soru cevabı

# %%
history_df['Perceptions of corruption'].quantile(q=0.75)

# quartile ları bu şekilde belirliyoruz
# Out:
# 0.869

# %%
history_df['Perceptions of corruption'].quantile(q=0.5)
# Out:
# 0.801

# %%
history_df['Perceptions of corruption'].quantile(q=0.25)
# Out:
# 0.68875

# %%
# şimdi bu değer aralıklarını fonksiyonda kullanabiliriz. böylece corruption numerik değerlerini
# descriptive olarak tanımalayacağız.

def trust(corrupt):
    if corrupt >= 0.869000:
        return "Low trust in institutions"
    elif corrupt >  0.801:
        return "Lower than normal level of trust"
    elif 0.801 >= corrupt > 0.68875:
        return "About the normal level trust"
    else :
        return "High level of trust"

# %%
history_df["Trust in institutions"] = history_df["Perceptions of corruption"].apply(trust)

# history_df'te Trust in institutions sütunu oluşturup, içine percentions of corruption değerlerinin 
# trust fonksiyonuna uygulanmış halini atadık.

# %%
history_df
# Out:
#        Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0       Afghanistan  2008        3.724               7.370           0.451
# 1       Afghanistan  2009        4.402               7.540           0.552
# 2       Afghanistan  2010        4.758               7.647           0.539
# 3       Afghanistan  2011        3.832               7.620           0.521
# 4       Afghanistan  2012        3.783               7.705           0.521
# ...             ...   ...          ...                 ...             ...
# 2093          China  2021        5.339               9.673           0.811
# 2094    New Zealand  2021        7.277              10.643           0.948
# 2095      Australia  2021        7.183              10.796           0.940
# 2096         Canada  2021        7.103              10.776           0.926
# 2097  United States  2021        6.951              11.023           0.920
#
# ...

# %% [markdown]
# # Vectorize'a bak
