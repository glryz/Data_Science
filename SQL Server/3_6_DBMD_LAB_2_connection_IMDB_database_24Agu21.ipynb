# %%
import pyodbc
import pandas as pd

# %% [markdown]
# **1- Import the "IMDB top 1000_LV.csv" dataset with Python.**

# %%
pwd
# Out:
# 'C:\\Users\\DataScience\\DSMLBC\\CW\\PYODBC\\SESSIONS'

# %%
df = pd.read_csv("IMDB top 1000_LV.csv")
df.head(2)
# Out:
#    Movie_ID                     Title Certificate  Duration         Genre  \
# 0         1  The Shawshank Redemption         13+       142         Drama
# 1         2             The Godfather          16       175  Crime, Drama
#
#    Rate  Metascore                                        Description  Year  \
# 0   9.3         80  Two imprisoned men bond over a number of years...  1994
# 1   9.2        100  An organized crime dynasty's aging patriarch t...  1972
#
#               Directors                                              Stars  \
# 0        Frank Darabont  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Francis Ford Coppola  Marlon Brando, Al Pacino, James Caan, Diane Ke...
#
#      Votes  Gross($M)
# 0  2377444      28.34
# 1  1646788     134.97

# %%
df.shape
# Out:
# (1000, 13)

# %% [markdown]
# **2- Create an empty table in a database with Python.**

# %%
def create_server_connection(driver, server, database, user, password):
    conn = None
    try:
        conn = pyodbc.connect(DRIVER=driver, SERVER=server, DATABASE=database, UID=user, PWD=password)
        print("Successful!")
    except Error as err:
        print(f"Error: '{err}'")
    return conn

driver = '{ODBC Driver 17 for SQL Server}'
server = 'localhost'
database = 'master'
user = 'sa'
password = '----'
conn = create_server_connection(driver, server, database, user, password)
# Out:
# Successful!

# %%
conn_string = "driver={ODBC Driver 17 for SQL Server}; server=localhost; database=master; TRUSTED_CONNECTION=yes;"

# %%
conn = pyodbc.connect(conn_string);

# %%
crs = conn.cursor()

# %%
conn.autocommit = True

# %%
def create_database(conn, create_database_query):
    crs = conn.cursor()
    try:
        crs.execute(create_database_query)
        print("Database is created successfully")
    except Error as err:
        print(f"Error: '{err}'")

# %%
create_database_query = 'CREATE DATABASE Test_DB'
create_database(conn, create_database_query)
# Out:
# Database is created successfully

# %%
def execute_query(conn, query):
    crs = conn.cursor()
    try:
        crs.execute(query)
        conn.commit()
        print("Query successful!")
    except Error as err:
        print(f"Error: '{err}'")

# %%
query = 'USE Test_DB'
execute_query(conn, query)
# Out:
# Query successful!

# %%
query = """
        CREATE TABLE imdb (
            Movie_ID INTEGER primary key,
            Title VARCHAR(255) NOT NULL,
            Certificate VARCHAR(255) NOT NULL,
            Duration INTEGER NOT NULL,
            Genre VARCHAR(255) NOT NULL,
            Rate FLOAT NOT NULL,
            Metascore INTEGER,
            Description VARCHAR(4096) NOT NULL,
            Year INTEGER NOT NULL,
            Directors VARCHAR(255) NOT NULL,
            Stars VARCHAR(255) NOT NULL,
            Votes INTEGER,
            Gross FLOAT
        )
        """
execute_query(conn, query)
# Out:
# Query successful!

# %% [markdown]
# **3- Insert the "IMDB top 1000_LV.csv" dataset into the database with Python.**

# %%
records = df.to_dict('records')

# %%
records

# %%
#for k,v in enumerate(records, start = 1):
 #   print(k,v)
# Out:
# 1 {'Movie_ID': 1, 'Title': 'The Shawshank Redemption', 'Certificate': '13+', 'Duration': 142, 'Genre': 'Drama', 'Rate': 9.3, 'Metascore': 80, 'Description': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.', 'Year': 1994, 'Directors': 'Frank Darabont', 'Stars': 'Tim Robbins, Morgan Freeman, Bob Gunton, William Sadler', 'Votes': 2377444, 'Gross($M)': 28.34}
# 2 {'Movie_ID': 2, 'Title': 'The Godfather', 'Certificate': '16', 'Duration': 175, 'Genre': 'Crime, Drama', 'Rate': 9.2, 'Metascore': 100, 'Description': "An organized crime dynasty's aging patriarch transfers control of his clandestine empire to his reluctant son.", 'Year': 1972, 'Directors': 'Francis Ford Coppola', 'Stars': 'Marlon Brando, Al Pacino, James Caan, Diane Keaton', 'Votes': 1646788, 'Gross($M)': 134.97}
# 3 {'Movie_ID': 3, 'Title': 'The Dark Knight', 'Certificate': '16', 'Duration': 152, 'Genre': 'Action, Crime, Drama', 'Rate': 9.0, 'Metascore': 84, 'Description': 'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.', 'Year': 2008, 'Directors': 'Christopher Nolan', 'Stars': 'Christian Bale, Heath Ledger, Aaron Eckhart, Michael Caine', 'Votes': 2341216, 'Gross($M)': 534.86}
# 4 {'Movie_ID': 4, 'Title': 'The Godfather: Part II', 'Certificate': '12', 'Duration': 202, 'Genre': 'Crime, Drama', 'Rate': 9.0, 'Metascore': 90, 'Description': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.', 'Year': 1974, 'Directors': 'Francis Ford Coppola', 'Stars': 'Al Pacino, Robert De Niro, Robert Duvall, Diane Keaton', 'Votes': 1146645, 'Gross($M)': 57.3}
# 5 {'Movie_ID': 5, 'Title': '12 Angry Men', 'Certificate': '14', 'Duration': 96, 'Genre': 'Crime, Drama', 'Rate': 9.0, 'Metascore': 96, 'Description': 'A jury holdout attempts to prevent a miscarriage of justice by forcing his colleagues to reconsider the evidence.', 'Year': 1957, 'Directors': 'Sidney Lumet', 'Stars': 'Henry Fonda, Lee J. Cobb, Martin Balsam, John Fiedler', 'Votes': 701877, 'Gross($M)': 4.36}
# 6 {'Movie_ID': 6, 'Title': 'The Lord of the Rings: The Return of the King', 'Certificate': '12', 'Duration': 201, 'Genre': 'Action, Adventure, Drama', 'Rate': 8.9, 'Metascore': 94, 'Description': "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.", 'Year': 2003, 'Directors': 'Peter Jackson', 'Stars': 'Elijah Wood, Viggo Mortensen, Ian McKellen, Orlando Bloom', 'Votes': 1663885, 'Gross($M)': 377.85}
# 7 {'Movie_ID': 7, 'Title': 'Pulp Fiction', 'Certificate': '18+', 'Duration': 154, 'Genre': 'Crime, Drama', 'Rate': 8.9, 'Metascore': 94, 'Description': 'The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.', 'Year': 1994, 'Directors': 'Quentin Tarantino', 'Stars': 'John Travolta, Uma Thurman, Samuel L. Jackson, Bruce Willis', 'Votes': 1852167, 'Gross($M)': 107.93}
# 8 {'Movie_ID': 8, 'Title': "Schindler's List", 'Certificate': '12', 'Duration': 195, 'Genre': 'Biography, Drama, History', 'Rate': 8.9, 'Metascore': 94, 'Description': 'In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.', 'Year': 1993, 'Directors': 'Steven Spielberg', 'Stars': 'Liam Neeson, Ralph Fiennes, Ben Kingsley, Caroline Goodall', 'Votes': 1229532, 'Gross($M)': 96.9}
# 9 {'Movie_ID': 9, 'Title': 'Inception', 'Certificate': '13+', 'Duration': 148, 'Genre': 'Action, Adventure, Sci-Fi', 'Rate': 8.8, 'Metascore': 74, 'Description': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O.', 'Year': 2010, 'Directors': 'Christopher Nolan', 'Stars': 'Leonardo DiCaprio, Joseph Gordon-Levitt, Elliot Page, Ken Watanabe', 'Votes': 2099808, 'Gross($M)': 292.58}
# 10 {'Movie_ID': 10, 'Title': 'Fight Club', 'Certificate': '18+', 'Duration': 139, 'Genre': 'Drama', 'Rate': 8.8, 'Metascore': 66, 'Description': 'A nameless first person narrator (Edward Norton) attends support groups in attempt to subdue his emotional state and relieve his insomniac state. When he meets Marla (Helena Bonham Carter),... See full summary »', 'Year': 1999, 'Directors': 'David Fincher', 'Stars': 'Brad Pitt, Edward Norton, Meat Loaf, Zach Grenier', 'Votes': 1881308, 'Gross($M)': 37.03}
# 11 {'Movie_ID': 11, 'Title': 'The Lord of the Rings: The Fellowship of the Ring', 'Certificate': '12', 'Duration': 178, 'Genre': 'Action, Adventure, Drama', 'Rate': 8.8, 'Metascore': 92, 'Description': 'A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.', 'Year': 2001, 'Directors': 'Peter Jackson', 'Stars': 'Elijah Wood, Ian McKellen, Orlando Bloom, Sean Bean', 'Votes': 1683966, 'Gross($M)': 315.54}
# 12 {'Movie_ID': 12, 'Title': 'Forrest Gump', 'Certificate': '7+', 'Duration': 142, 'Genre': 'Drama, Romance', 'Rate': 8.8, 'Metascore': 82, 'Description': 'The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.', 'Year': 1994, 'Directors': 'Robert Zemeckis', 'Stars': 'Tom Hanks, Robin Wright, Gary Sinise, Sally Field', 'Votes': 1838878, 'Gross($M)': 330.25}
# 13 {'Movie_ID': 13, 'Title': 'Il buono', 'Certificate': '12', 'Duration': 161, 'Genre': 'Western', 'Rate': 8.8, 'Metascore': 90, 'Description': 'A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.', 'Year': 1966, 'Directors': 'Sergio Leone', 'Stars': 'Clint Eastwood, Eli Wallach, Lee Van Cleef, Aldo Giuffr', 'Votes': 697048, 'Gross($M)': 6.1}
# 14 {'Movie_ID': 14, 'Title': 'The Lord of the Rings: The Two Towers', 'Certificate': '12', 'Duration': 179, 'Genre': 'Action, Adventure, Drama', 'Rate': 8.7, 'Metascore': 87, 'Description': "While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.", 'Year': 2002, 'Directors': 'Peter Jackson', 'Stars': 'Elijah Wood, Ian McKellen, Viggo Mortensen, Orlando Bloom', 'Votes': 1504596, 'Gross($M)': 342.55}
# 15 {'Movie_ID': 15, 'Title': 'The Matrix', 'Certificate': '16', 'Duration': 136, 'Genre': 'Action, Sci-Fi', 'Rate': 8.7, 'Metascore': 73, 'Description': 'When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.', 'Year': 1999, 'Directors': 'Lana Wachowski, Lilly Wachowski', 'Stars': 'Keanu Reeves, Laurence Fishburne, Carrie-Anne Moss, Hugo Weaving', 'Votes': 1700486, 'Gross($M)': 171.48}
# 16 {'Movie_ID': 16, 'Title': 'Goodfellas', 'Certificate': '18+', 'Duration': 146, 'Genre': 'Biography, Crime, Drama', 'Rate': 8.7, 'Metascore': 90, 'Description': 'The story of Henry Hill and his life in the mob, covering his relationship with his wife Karen Hill and his mob partners Jimmy Conway and Tommy DeVito in the Italian-American crime syndicate.', 'Year': 1990, 'Directors': 'Martin Scorsese', 'Stars': 'Robert De Niro, Ray Liotta, Joe Pesci, Lorraine Bracco', 'Votes': 1036632, 'Gross($M)': 46.84}
# 17 {'Movie_ID': 17, 'Title': 'Star Wars: Episode V - The Empire Strikes Back', 'Certificate': '12', 'Duration': 124, 'Genre': 'Action, Adventure, Fantasy', 'Rate': 8.7, 'Metascore': 82, 'Description': 'After the Rebels are brutally overpowered by the Empire on the ice planet Hoth, Luke Skywalker begins Jedi training with Yoda, while his friends are pursued by Darth Vader and a bounty hunter named Boba Fett all over the galaxy.', 'Year': 1980, 'Directors': 'Irvin Kershner', 'Stars': 'Mark Hamill, Harrison Ford, Carrie Fisher, Billy Dee Williams', 'Votes': 1173195, 'Gross($M)': 290.48}
# 18 {'Movie_ID': 18, 'Title': "One Flew Over the Cuckoo's Nest", 'Certificate': '15+', 'Duration': 133, 'Genre': 'Drama', 'Rate': 8.7, 'Metascore': 83, 'Description': 'A criminal pleads insanity and is admitted to a mental institution, where he rebels against the oppressive nurse and rallies up the scared patients.', 'Year': 1975, 'Directors': 'Milos Forman', 'Stars': 'Jack Nicholson, Louise Fletcher, Michael Berryman, Peter Brocco', 'Votes': 929061, 'Gross($M)': 112.0}
# 19 {'Movie_ID': 19, 'Title': 'Gisaengchung', 'Certificate': '15+', 'Duration': 132, 'Genre': 'Comedy, Drama, Thriller', 'Rate': 8.6, 'Metascore': 96, 'Description': 'Greed and class discrimination threaten the newly formed symbiotic relationship between the wealthy Park family and the destitute Kim clan.', 'Year': 2019, 'Directors': 'Bong Joon Ho', 'Stars': 'Kang-ho Song, Sun-kyun Lee, Yeo-jeong Cho, Woo-sik Choi', 'Votes': 591063, 'Gross($M)': 53.37}
# 20 {'Movie_ID': 20, 'Title': 'Soorarai Pottru', 'Certificate': 'None', 'Duration': 153, 'Genre': 'Drama', 'Rate': 8.6, 'Metascore': 0, 'Description': 'Nedumaaran Rajangam "Maara" sets out to make the common man fly and in the process takes on the world\'s most capital intensive industry and several enemies who stand in his way.', 'Year': 2020, 'Directors': 'Sudha Kongara', 'Stars': 'Suriya, Madhavan, Aparna Balamurali, Paresh Rawal', 'Votes': 58429, 'Gross($M)': 0.0}
# 21 {'Movie_ID': 21, 'Title': 'Interstellar', 'Certificate': '13A', 'Duration': 169, 'Genre': 'Adventure, Drama, Sci-Fi', 'Rate': 8.6, 'Metascore': 74, 'Description': "A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.", 'Year': 2014, 'Directors': 'Christopher Nolan', 'Stars': 'Matthew McConaughey, Anne Hathaway, Jessica Chastain, Mackenzie Foy', 'Votes': 1544156, 'Gross($M)': 188.02}
# 22 {'Movie_ID': 22, 'Title': 'Cidade de Deus', 'Certificate': '16', 'Duration': 130, 'Genre': 'Crime, Drama', 'Rate': 8.6, 'Metascore': 79, 'Description': "In the slums of Rio, two kids' paths diverge as one struggles to become a photographer and the other a kingpin.", 'Year': 2002, 'Directors': 'Fernando Meirelles, Kátia Lund', 'Stars': 'Alexandre Rodrigues, Leandro Firmino, Matheus Nachtergaele, Phellipe Haagensen', 'Votes': 706466, 'Gross($M)': 7.56}
# 23 {'Movie_ID': 23, 'Title': 'Sen to Chihiro no kamikakushi', 'Certificate': 'G', 'Duration': 125, 'Genre': 'Animation, Adventure, Family', 'Rate': 8.6, 'Metascore': 96, 'Description': "During her family's move to the suburbs, a sullen 10-year-old girl wanders into a world ruled by gods, witches, and spirits, and where humans are changed into beasts.", 'Year': 2001, 'Directors': 'Hayao Miyazaki', 'Stars': 'Daveigh Chase, Suzanne Pleshette, Miyu Irino, Rumi Hiiragi', 'Votes': 665086, 'Gross($M)': 10.06}
# 24 {'Movie_ID': 24, 'Title': 'Saving Private Ryan', 'Certificate': '16', 'Duration': 169, 'Genre': 'Drama, War', 'Rate': 8.6, 'Metascore': 91, 'Description': 'Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.', 'Year': 1998, 'Directors': 'Steven Spielberg', 'Stars': 'Tom Hanks, Matt Damon, Tom Sizemore, Edward Burns', 'Votes': 1253808, 'Gross($M)': 216.54}
# 25 {'Movie_ID': 25, 'Title': 'The Green Mile', 'Certificate': '16', 'Duration': 189, 'Genre': 'Crime, Drama, Fantasy', 'Rate': 8.6, 'Metascore': 61, 'Description': 'The lives of guards on Death Row are affected by one of their charges: a black man accused of child murder and rape, yet who has a mysterious gift.', 'Year': 1999, 'Directors': 'Frank Darabont', 'Stars': 'Tom Hanks, Michael Clarke Duncan, David Morse, Bonnie Hunt', 'Votes': 1166205, 'Gross($M)': 136.8}
# 26 {'Movie_ID': 26, 'Title': 'La vita Ã¨ bella', 'Certificate': 'AL', 'Duration': 116, 'Genre': 'Comedy, Drama, Romance', 'Rate': 8.6, 'Metascore': 0, 'Description': 'When an open-minded Jewish librarian and his son become victims of the Holocaust, he uses a perfect mixture of will, humor, and imagination to protect his son from the dangers around their camp.', 'Year': 1997, 'Directors': 'Roberto Benigni', 'Stars': 'Roberto Benigni, Nicoletta Braschi, Giorgio Cantarini, Giustino Durano', 'Votes': 633117, 'Gross($M)': 57.6}
# 27 {'Movie_ID': 27, 'Title': 'Se7en', 'Certificate': '13+', 'Duration': 127, 'Genre': 'Crime, Drama, Mystery', 'Rate': 8.6, 'Metascore': 65, 'Description': 'Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.', 'Year': 1995, 'Directors': 'David Fincher', 'Stars': 'Morgan Freeman, Brad Pitt, Kevin Spacey, Andrew Kevin Walker', 'Votes': 1467933, 'Gross($M)': 100.13}
# 28 {'Movie_ID': 28, 'Title': 'The Silence of the Lambs', 'Certificate': '18+', 'Duration': 118, 'Genre': 'Crime, Drama, Thriller', 'Rate': 8.6, 'Metascore': 85, 'Description': 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.', 'Year': 1991, 'Directors': 'Jonathan Demme', 'Stars': 'Jodie Foster, Anthony Hopkins, Lawrence A. Bonney, Kasi Lemmons', 'Votes': 1290491, 'Gross($M)': 130.74}
# 29 {'Movie_ID': 29, 'Title': 'Star Wars', 'Certificate': 'AL', 'Duration': 121, 'Genre': 'Action, Adventure, Fantasy', 'Rate': 8.6, 'Metascore': 90, 'Description': "Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, a Wookiee and two droids to save the galaxy from the Empire's world-destroying battle station, while also attempting to rescue Princess Leia from the mysterious Darth Vader.", 'Year': 1977, 'Directors': 'George Lucas', 'Stars': 'Mark Hamill, Harrison Ford, Carrie Fisher, Alec Guinness', 'Votes': 1245194, 'Gross($M)': 322.74}
# 30 {'Movie_ID': 30, 'Title': 'Seppuku', 'Certificate': 'None', 'Duration': 133, 'Genre': 'Action, Drama, Mystery', 'Rate': 8.6, 'Metascore': 85, 'Description': "When a ronin requesting seppuku at a feudal lord's palace is told of the brutal suicide of another ronin who previously visited, he reveals how their pasts are intertwined - and in doing so challenges the clan's integrity.", 'Year': 1962, 'Directors': 'Masaki Kobayashi', 'Stars': 'Tatsuya Nakadai, Akira Ishihama, Shima Iwashita, Tetsurô Tanba', 'Votes': 44166, 'Gross($M)': 0.0}
# 31 {'Movie_ID': 31, 'Title': 'Shichinin no samurai', 'Certificate': '12', 'Duration': 207, 'Genre': 'Action, Adventure, Drama', 'Rate': 8.6, 'Metascore': 98, 'Description': 'A poor village under attack by bandits recruits seven unemployed samurai to help them defend themselves.', 'Year': 1954, 'Directors': 'Akira Kurosawa', 'Stars': 'Toshirô Mifune, Takashi Shimura, Keiko Tsushima, Yukiko Shimazaki', 'Votes': 319841, 'Gross($M)': 0.27}
# 32 {'Movie_ID': 32, 'Title': "It's a Wonderful Life", 'Certificate': '6', 'Duration': 130, 'Genre': 'Drama, Family, Fantasy', 'Rate': 8.6, 'Metascore': 89, 'Description': 'An angel is sent from Heaven to help a desperately frustrated businessman by showing him what life would have been like if he had never existed.', 'Year': 1946, 'Directors': 'Frank Capra', 'Stars': 'James Stewart, Donna Reed, Lionel Barrymore, Thomas Mitchell', 'Votes': 410691, 'Gross($M)': 0.0}
# 33 {'Movie_ID': 33, 'Title': 'Hamilton', 'Certificate': '12', 'Duration': 160, 'Genre': 'Biography, Drama, History', 'Rate': 8.5, 'Metascore': 90, 'Description': "The real life of one of America's foremost founding fathers and first Secretary of the Treasury, Alexander Hamilton. Captured live on Broadway from the Richard Rodgers Theater with the original Broadway cast.", 'Year': 2020, 'Directors': 'Thomas Kail', 'Stars': 'Lin-Manuel Miranda, Phillipa Soo, Leslie Odom Jr., Renée Elise Goldsberry', 'Votes': 62245, 'Gross($M)': 0.0}
# 34 {'Movie_ID': 34, 'Title': 'Ratsasan', 'Certificate': 'None', 'Duration': 170, 'Genre': 'Action, Crime, Thriller', 'Rate': 8.5, 'Metascore': 0, 'Description': 'A sub-inspector sets out in pursuit of a mysterious serial killer who targets teen school girls and murders them brutally.', 'Year': 2018, 'Directors': 'Ram Kumar', 'Stars': 'Vishnu Vishal, Amala Paul, Radha Ravi, Sangili Murugan', 'Votes': 27332, 'Gross($M)': 0.0}
# 35 {'Movie_ID': 35, 'Title': 'Whiplash', 'Certificate': '13+', 'Duration': 106, 'Genre': 'Drama, Music', 'Rate': 8.5, 'Metascore': 88, 'Description': "A promising young drummer enrolls at a cut-throat music conservatory where his dreams of greatness are mentored by an instructor who will stop at nothing to realize a student's potential.", 'Year': 2014, 'Directors': 'Damien Chazelle', 'Stars': 'Miles Teller, J.K. Simmons, Melissa Benoist, Paul Reiser', 'Votes': 732397, 'Gross($M)': 13.09}
# 36 {'Movie_ID': 36, 'Title': 'The Intouchables', 'Certificate': '12', 'Duration': 112, 'Genre': 'Biography, Comedy, Drama', 'Rate': 8.5, 'Metascore': 0, 'Description': 'After he becomes a quadriplegic from a paragliding accident, an aristocrat hires a young man from the projects to be his caregiver.', 'Year': 2011, 'Directors': 'Olivier Nakache, Éric Toledano', 'Stars': 'François Cluzet, Omar Sy, Anne Le Ny, Audrey Fleurot', 'Votes': 773582, 'Gross($M)': 13.18}
# 37 {'Movie_ID': 37, 'Title': 'The Prestige', 'Certificate': '12', 'Duration': 130, 'Genre': 'Drama, Mystery, Sci-Fi', 'Rate': 8.5, 'Metascore': 66, 'Description': 'After a tragic accident, two stage magicians engage in a battle to create the ultimate illusion while sacrificing everything they have to outwit each other.', 'Year': 2006, 'Directors': 'Christopher Nolan', 'Stars': 'Christian Bale, Hugh Jackman, Scarlett Johansson, Michael Caine', 'Votes': 1208154, 'Gross($M)': 53.09}
# 38 {'Movie_ID': 38, 'Title': 'The Departed', 'Certificate': '16', 'Duration': 151, 'Genre': 'Crime, Drama, Thriller', 'Rate': 8.5, 'Metascore': 85, 'Description': 'An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.', 'Year': 2006, 'Directors': 'Martin Scorsese', 'Stars': 'Leonardo DiCaprio, Matt Damon, Jack Nicholson, Mark Wahlberg', 'Votes': 1206348, 'Gross($M)': 132.38}
# 39 {'Movie_ID': 39, 'Title': 'The Pianist', 'Certificate': '12', 'Duration': 150, 'Genre': 'Biography, Drama, Music', 'Rate': 8.5, 'Metascore': 85, 'Description': 'A Polish Jewish musician struggles to survive the destruction of the Warsaw ghetto of World War II.', 'Year': 2002, 'Directors': 'Roman Polanski', 'Stars': 'Adrien Brody, Thomas Kretschmann, Frank Finlay, Emilia Fox', 'Votes': 743213, 'Gross($M)': 32.57}
# 40 {'Movie_ID': 40, 'Title': 'Gladiator', 'Certificate': '16', 'Duration': 155, 'Genre': 'Action, Adventure, Drama', 'Rate': 8.5, 'Metascore': 67, 'Description': 'A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.', 'Year': 2000, 'Directors': 'Ridley Scott', 'Stars': 'Russell Crowe, Joaquin Phoenix, Connie Nielsen, Oliver Reed', 'Votes': 1358912, 'Gross($M)': 187.71}
# 41 {'Movie_ID': 41, 'Title': 'American History X', 'Certificate': '18+', 'Duration': 119, 'Genre': 'Drama', 'Rate': 8.5, 'Metascore': 62, 'Description': 'A former neo-nazi skinhead tries to prevent his younger brother from going down the same wrong path that he did.', 'Year': 1998, 'Directors': 'Tony Kaye', 'Stars': "Edward Norton, Edward Furlong, Beverly D'Angelo, Jennifer Lien", 'Votes': 1045374, 'Gross($M)': 6.72}
# 42 {'Movie_ID': 42, 'Title': 'The Usual Suspects', 'Certificate': '16', 'Duration': 106, 'Genre': 'Crime, Mystery, Thriller', 'Rate': 8.5, 'Metascore': 77, 'Description': 'A sole survivor tells of the twisty events leading up to a horrific gun battle on a boat, which began when five criminals met at a seemingly random police lineup.', 'Year': 1995, 'Directors': 'Bryan Singer', 'Stars': 'Kevin Spacey, Gabriel Byrne, Chazz Palminteri, Stephen Baldwin', 'Votes': 1002784, 'Gross($M)': 23.34}
# 43 {'Movie_ID': 43, 'Title': 'LÃ©on', 'Certificate': '16', 'Duration': 110, 'Genre': 'Action, Crime, Drama', 'Rate': 8.5, 'Metascore': 64, 'Description': "Mathilda, a 12-year-old girl, is reluctantly taken in by Léon, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his protégée and learns the assassin's trade.", 'Year': 1994, 'Directors': 'Luc Besson', 'Stars': 'Jean Reno, Gary Oldman, Natalie Portman, Danny Aiello', 'Votes': 1050276, 'Gross($M)': 19.5}
# 44 {'Movie_ID': 44, 'Title': 'The Lion King', 'Certificate': 'AL', 'Duration': 88, 'Genre': 'Animation, Adventure, Drama', 'Rate': 8.5, 'Metascore': 88, 'Description': 'Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.', 'Year': 1994, 'Directors': 'Roger Allers, Rob Minkoff', 'Stars': 'Matthew Broderick, Jeremy Irons, James Earl Jones, Whoopi Goldberg', 'Votes': 956022, 'Gross($M)': 422.78}
# 45 {'Movie_ID': 45, 'Title': 'Terminator 2: Judgment Day', 'Certificate': '15+', 'Duration': 137, 'Genre': 'Action, Sci-Fi', 'Rate': 8.5, 'Metascore': 75, 'Description': 'A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her ten year old son, John Connor, from a more advanced and powerful cyborg.', 'Year': 1991, 'Directors': 'James Cameron', 'Stars': 'Arnold Schwarzenegger, Linda Hamilton, Edward Furlong, Robert Patrick', 'Votes': 1006231, 'Gross($M)': 204.84}
# 46 {'Movie_ID': 46, 'Title': 'Nuovo Cinema Paradiso', 'Certificate': '9', 'Duration': 155, 'Genre': 'Drama, Romance', 'Rate': 8.5, 'Metascore': 80, 'Description': "A filmmaker recalls his childhood when falling in love with the pictures at the cinema of his home village and forms a deep friendship with the cinema's projectionist.", 'Year': 1988, 'Directors': 'Giuseppe Tornatore', 'Stars': 'Philippe Noiret, Enzo Cannavale, Antonella Attili, Isa Danieli', 'Votes': 234738, 'Gross($M)': 11.99}
# 47 {'Movie_ID': 47, 'Title': 'Hotaru no haka', 'Certificate': 'None', 'Duration': 89, 'Genre': 'Animation, Drama, War', 'Rate': 8.5, 'Metascore': 94, 'Description': 'A young boy and his little sister struggle to survive in Japan during World War II.', 'Year': 1988, 'Directors': 'Isao Takahata', 'Stars': 'Tsutomu Tatsumi, Ayano Shiraishi, Akemi Yamaguchi, Yoshiko Shinohara', 'Votes': 240623, 'Gross($M)': 0.0}
# 48 {'Movie_ID': 48, 'Title': 'Back to the Future', 'Certificate': 'AL', 'Duration': 116, 'Genre': 'Adventure, Comedy, Sci-Fi', 'Rate': 8.5, 'Metascore': 87, 'Description': 'Marty McFly, a 17-year-old high school student, is accidentally sent thirty years into the past in a time-traveling DeLorean invented by his close friend, the eccentric scientist Doc Brown.', 'Year': 1985, 'Directors': 'Robert Zemeckis', 'Stars': 'Michael J. Fox, Christopher Lloyd, Lea Thompson, Crispin Glover', 'Votes': 1074658, 'Gross($M)': 210.61}
# 49 {'Movie_ID': 49, 'Title': 'Once Upon a Time in the West', 'Certificate': '12', 'Duration': 165, 'Genre': 'Western', 'Rate': 8.5, 'Metascore': 80, 'Description': 'A mysterious stranger with a harmonica joins forces with a notorious desperado to protect a beautiful widow from a ruthless assassin working for the railroad.', 'Year': 1968, 'Directors': 'Sergio Leone', 'Stars': 'Henry Fonda, Charles Bronson, Claudia Cardinale, Jason Robards', 'Votes': 306432, 'Gross($M)': 5.32}
# 50 {'Movie_ID': 50, 'Title': 'Psycho', 'Certificate': '18', 'Duration': 109, 'Genre': 'Horror, Mystery, Thriller', 'Rate': 8.5, 'Metascore': 97, 'Description': "A Phoenix secretary embezzles $40,000 from her employer's client, goes on the run, and checks into a remote motel run by a young man under the domination of his mother.", 'Year': 1960, 'Directors': 'Alfred Hitchcock', 'Stars': 'Anthony Perkins, Janet Leigh, Vera Miles, John Gavin', 'Votes': 612344, 'Gross($M)': 32.0}
# 51 {'Movie_ID': 51, 'Title': 'Casablanca', 'Certificate': 'AL', 'Duration': 102, 'Genre': 'Drama, Romance, War', 'Rate': 8.5, 'Metascore': 100, 'Description': 'A cynical expatriate American cafe owner struggles to decide whether or not to help his former lover and her fugitive husband escape the Nazis in French Morocco.', 'Year': 1942, 'Directors': 'Michael Curtiz', 'Stars': 'Humphrey Bogart, Ingrid Bergman, Paul Henreid, Claude Rains', 'Votes': 528239, 'Gross($M)': 1.02}
# 52 {'Movie_ID': 52, 'Title': 'Modern Times', 'Certificate': 'AL', 'Duration': 87, 'Genre': 'Comedy, Drama, Family', 'Rate': 8.5, 'Metascore': 96, 'Description': 'The Tramp struggles to live in modern industrial society with the help of a young homeless woman.', 'Year': 1936, 'Directors': 'Charles Chaplin', 'Stars': 'Charles Chaplin, Paulette Goddard, Henry Bergman, Tiny Sandford', 'Votes': 221337, 'Gross($M)': 0.16}
# 53 {'Movie_ID': 53, 'Title': 'City Lights', 'Certificate': '14', 'Duration': 87, 'Genre': 'Comedy, Drama, Romance', 'Rate': 8.5, 'Metascore': 99, 'Description': 'With the aid of a wealthy erratic tippler, a dewy-eyed tramp who has fallen in love with a sightless flower girl accumulates money to be able to help her medically.', 'Year': 1931, 'Directors': 'Charles Chaplin', 'Stars': 'Charles Chaplin, Virginia Cherrill, Florence Lee, Harry Myers', 'Votes': 170184, 'Gross($M)': 0.02}
# 54 {'Movie_ID': 54, 'Title': 'CapharnaÃ¼m', 'Certificate': '9', 'Duration': 126, 'Genre': 'Drama', 'Rate': 8.4, 'Metascore': 75, 'Description': 'While serving a five-year sentence for a violent crime, a 12-year-old boy sues his parents for neglect.', 'Year': 2018, 'Directors': 'Nadine Labaki', 'Stars': 'Zain Al Rafeea, Yordanos Shiferaw, Boluwatife Treasure Bankole, Kawsar Al Haddad', 'Votes': 67105, 'Gross($M)': 1.66}
# 55 {'Movie_ID': 55, 'Title': 'Joker', 'Certificate': '18+', 'Duration': 122, 'Genre': 'Crime, Drama, Thriller', 'Rate': 8.4, 'Metascore': 0, 'Description': 'In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.', 'Year': 2019, 'Directors': 'Todd Phillips', 'Stars': 'Joaquin Phoenix, Robert De Niro, Zazie Beetz, Frances Conroy', 'Votes': 981464, 'Gross($M)': 335.45}
# 56 {'Movie_ID': 56, 'Title': 'Ayla: The Daughter of War', 'Certificate': '7+', 'Duration': 125, 'Genre': 'Biography, Drama, History', 'Rate': 8.4, 'Metascore': 0, 'Description': 'In 1950, amid-st the ravages of the Korean War, Sergeant Süleyman stumbles upon a half-frozen little girl, with no parents and no help in sight. Frantic, scared and on the verge of death, ... See full summary »', 'Year': 2017, 'Directors': 'Can Ulkay', 'Stars': 'Çetin Tekindor, Ismail Hacioglu, Kyung-jin Lee, Kim Seol', 'Votes': 35120, 'Gross($M)': 0.0}
# 57 {'Movie_ID': 57, 'Title': 'Vikram Vedha', 'Certificate': 'None', 'Duration': 147, 'Genre': 'Action, Crime, Drama', 'Rate': 8.4, 'Metascore': 0, 'Description': "Vikram, a no-nonsense police officer, accompanied by Simon, his partner, is on the hunt to capture Vedha, a smuggler and a murderer. Vedha tries to change Vikram's life, which leads to a conflict.", 'Year': 2017, 'Directors': 'Gayatri, Pushkar', 'Stars': 'Madhavan, Vijay Sethupathi, Shraddha Srinath, Kathir', 'Votes': 29629, 'Gross($M)': 0.0}
# 58 {'Movie_ID': 58, 'Title': 'Kimi no na wa.', 'Certificate': '7+', 'Duration': 106, 'Genre': 'Animation, Drama, Fantasy', 'Rate': 8.4, 'Metascore': 79, 'Description': 'Two strangers find themselves linked in a bizarre way. When a connection forms, will distance be the only thing to keep them apart?', 'Year': 2016, 'Directors': 'Makoto Shinkai', 'Stars': 'Ry', 'Votes': 204590, 'Gross($M)': 5.02}
# 59 {'Movie_ID': 59, 'Title': 'Dangal', 'Certificate': '9', 'Duration': 161, 'Genre': 'Action, Biography, Drama', 'Rate': 8.4, 'Metascore': 0, 'Description': 'Former wrestler Mahavir Singh Phogat and his two wrestler daughters struggle towards glory at the Commonwealth Games in the face of societal oppression.', 'Year': 2016, 'Directors': 'Nitesh Tiwari', 'Stars': 'Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh, Sanya Malhotra', 'Votes': 160712, 'Gross($M)': 12.39}
# 60 {'Movie_ID': 60, 'Title': 'Spider-Man: Into the Spider-Verse', 'Certificate': '7+', 'Duration': 117, 'Genre': 'Animation, Action, Adventure', 'Rate': 8.4, 'Metascore': 87, 'Description': 'Teen Miles Morales becomes the Spider-Man of his universe, and must join with five spider-powered individuals from other dimensions to stop a threat for all realities.', 'Year': 2018, 'Directors': 'Bob Persichetti, Peter Ramsey, Rodney Rothman', 'Stars': 'Shameik Moore, Jake Johnson, Hailee Steinfeld, Mahershala Ali', 'Votes': 392602, 'Gross($M)': 190.24}
# 61 {'Movie_ID': 61, 'Title': 'Avengers: Endgame', 'Certificate': '15A', 'Duration': 181, 'Genre': 'Action, Adventure, Drama', 'Rate': 8.4, 'Metascore': 78, 'Description': "After the devastating events of Avengers: Sonsuzluk Savaşı (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe.", 'Year': 2019, 'Directors': 'Anthony Russo, Joe Russo', 'Stars': 'Robert Downey Jr., Chris Evans, Mark Ruffalo, Chris Hemsworth', 'Votes': 856383, 'Gross($M)': 858.37}
# 62 {'Movie_ID': 62, 'Title': 'Avengers: Infinity War', 'Certificate': '13+', 'Duration': 149, 'Genre': 'Action, Adventure, Sci-Fi', 'Rate': 8.4, 'Metascore': 68, 'Description': 'The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.', 'Year': 2018, 'Directors': 'Anthony Russo, Joe Russo', 'Stars': 'Robert Downey Jr., Chris Hemsworth, Mark Ruffalo, Chris Evans', 'Votes': 865375, 'Gross($M)': 678.82}
# 63 {'Movie_ID': 63, 'Title': 'Coco', 'Certificate': '7+', 'Duration': 105, 'Genre': 'Animation, Adventure, Family', 'Rate': 8.4, 'Metascore': 81, 'Description': "Aspiring musician Miguel, confronted with his family's ancestral ban on music, enters the Land of the Dead to find his great-great-grandfather, a legendary singer.", 'Year': 2017, 'Directors': 'Lee Unkrich, Adrian Molina', 'Stars': 'Anthony Gonzalez, Gael Garc', 'Votes': 399434, 'Gross($M)': 209.73}
# 64 {'Movie_ID': 64, 'Title': 'Django Unchained', 'Certificate': '18+', 'Duration': 165, 'Genre': 'Drama, Western', 'Rate': 8.4, 'Metascore': 81, 'Description': 'With the help of a German bounty-hunter, a freed slave sets out to rescue his wife from a brutal plantation-owner in Mississippi.', 'Year': 2012, 'Directors': 'Quentin Tarantino', 'Stars': 'Jamie Foxx, Christoph Waltz, Leonardo DiCaprio, Kerry Washington', 'Votes': 1379947, 'Gross($M)': 162.81}
# 65 {'Movie_ID': 65, 'Title': 'The Dark Knight Rises', 'Certificate': '13A', 'Duration': 164, 'Genre': 'Action, Adventure', 'Rate': 8.4, 'Metascore': 78, 'Description': "Eight years after the Joker's reign of anarchy, Batman, with the help of the enigmatic Catwoman, is forced from his exile to save Gotham City from the brutal guerrilla terrorist Bane.", 'Year': 2012, 'Directors': 'Christopher Nolan', 'Stars': 'Christian Bale, Tom Hardy, Anne Hathaway, Gary Oldman', 'Votes': 1536563, 'Gross($M)': 448.14}
# 66 {'Movie_ID': 66, 'Title': '3 Idiots', 'Certificate': 'PG-13', 'Duration': 170, 'Genre': 'Comedy, Drama', 'Rate': 8.4, 'Metascore': 67, 'Description': 'Two friends are searching for their long lost companion. They revisit their college days and recall the memories of their friend who inspired them to think differently, even as the rest of the world called them "idiots".', 'Year': 2009, 'Directors': 'Rajkumar Hirani', 'Stars': 'Aamir Khan, Madhavan, Mona Singh, Sharman Joshi', 'Votes': 350489, 'Gross($M)': 6.53}
# 67 {'Movie_ID': 67, 'Title': 'Taare Zameen Par', 'Certificate': 'PG', 'Duration': 165, 'Genre': 'Drama, Family', 'Rate': 8.4, 'Metascore': 0, 'Description': 'An eight-year-old boy is thought to be a lazy trouble-maker, until the new art teacher has the patience and compassion to discover the real problem behind his struggles in school.', 'Year': 2007, 'Directors': 'Aamir Khan, Amole Gupte', 'Stars': 'Darsheel Safary, Aamir Khan, Tisca Chopra, Vipin Sharma', 'Votes': 172562, 'Gross($M)': 1.22}
# 68 {'Movie_ID': 68, 'Title': 'WALLÂ·E', 'Certificate': 'AL', 'Duration': 98, 'Genre': 'Animation, Adventure, Family', 'Rate': 8.4, 'Metascore': 95, 'Description': 'In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.', 'Year': 2008, 'Directors': 'Andrew Stanton', 'Stars': 'Ben Burtt, Elissa Knight, Jeff Garlin, Fred Willard', 'Votes': 1013455, 'Gross($M)': 223.81}
# 69 {'Movie_ID': 69, 'Title': 'The Lives of Others', 'Certificate': '12', 'Duration': 137, 'Genre': 'Drama, Mystery, Thriller', 'Rate': 8.4, 'Metascore': 89, 'Description': 'In 1984 East Berlin, an agent of the secret police, conducting surveillance on a writer and his lover, finds himself becoming increasingly absorbed by their lives.', 'Year': 2006, 'Directors': 'Florian Henckel von Donnersmarck', 'Stars': 'Ulrich Mühe, Martina Gedeck, Sebastian Koch, Ulrich Tukur', 'Votes': 363555, 'Gross($M)': 11.29}
# 70 {'Movie_ID': 70, 'Title': 'Oldeuboi', 'Certificate': '18+', 'Duration': 120, 'Genre': 'Action, Drama, Mystery', 'Rate': 8.4, 'Metascore': 77, 'Description': 'After being kidnapped and imprisoned for fifteen years, Oh Dae-Su is released, only to find that he must find his captor in five days.', 'Year': 2003, 'Directors': 'Chan-wook Park', 'Stars': 'Choi Min-sik, Yoo Ji-Tae, Kang Hye-jeong, Kim Byeong-Ok', 'Votes': 523547, 'Gross($M)': 0.71}
# 71 {'Movie_ID': 71, 'Title': 'Memento', 'Certificate': '16', 'Duration': 113, 'Genre': 'Mystery, Thriller', 'Rate': 8.4, 'Metascore': 80, 'Description': "A man with short-term memory loss attempts to track down his wife's murderer.", 'Year': 2000, 'Directors': 'Christopher Nolan', 'Stars': 'Guy Pearce, Carrie-Anne Moss, Joe Pantoliano, Mark Boone Junior', 'Votes': 1139167, 'Gross($M)': 25.54}
# 72 {'Movie_ID': 72, 'Title': 'Mononoke-hime', 'Certificate': 'PG-13', 'Duration': 134, 'Genre': 'Animation, Action, Adventure', 'Rate': 8.4, 'Metascore': 76, 'Description': "On a journey to find the cure for a Tatarigami's curse, Ashitaka finds himself in the middle of a war between the forest gods and Tatara, a mining colony. In this quest he also meets San, the Mononoke Hime.", 'Year': 1997, 'Directors': 'Hayao Miyazaki', 'Stars': 'Yôji Matsuda, Yuriko Ishida, Y', 'Votes': 350006, 'Gross($M)': 2.38}
# 73 {'Movie_ID': 73, 'Title': 'Once Upon a Time in America', 'Certificate': '18+', 'Duration': 229, 'Genre': 'Crime, Drama', 'Rate': 8.4, 'Metascore': 0, 'Description': 'A former Prohibition-era Jewish gangster returns to the Lower East Side of Manhattan over thirty years later, where he once again must confront the ghosts and regrets of his old life.', 'Year': 1984, 'Directors': 'Sergio Leone', 'Stars': 'Robert De Niro, James Woods, Elizabeth McGovern, Treat Williams', 'Votes': 316389, 'Gross($M)': 5.32}
# 74 {'Movie_ID': 74, 'Title': 'Raiders of the Lost Ark', 'Certificate': '12', 'Duration': 115, 'Genre': 'Action, Adventure', 'Rate': 8.4, 'Metascore': 85, 'Description': "In 1936, archaeologist and adventurer Indiana Jones is hired by the U.S. government to find the Ark of the Covenant before Adolf Hitler's Nazis can obtain its awesome powers.", 'Year': 1981, 'Directors': 'Steven Spielberg', 'Stars': 'Harrison Ford, Karen Allen, Paul Freeman, John Rhys-Davies', 'Votes': 893316, 'Gross($M)': 248.16}
# 75 {'Movie_ID': 75, 'Title': 'The Shining', 'Certificate': '18+', 'Duration': 146, 'Genre': 'Drama, Horror', 'Rate': 8.4, 'Metascore': 66, 'Description': 'A family heads to an isolated hotel for the winter where a sinister presence influences the father into violence, while his psychic son sees horrific forebodings from both past and future.', 'Year': 1980, 'Directors': 'Stanley Kubrick', 'Stars': 'Jack Nicholson, Shelley Duvall, Danny Lloyd, Scatman Crothers', 'Votes': 911791, 'Gross($M)': 44.02}
# 76 {'Movie_ID': 76, 'Title': 'Apocalypse Now', 'Certificate': '16', 'Duration': 147, 'Genre': 'Drama, Mystery, War', 'Rate': 8.4, 'Metascore': 94, 'Description': 'A U.S. Army officer serving in Vietnam is tasked with assassinating a renegade Special Forces Colonel who sees himself as a god.', 'Year': 1979, 'Directors': 'Francis Ford Coppola', 'Stars': 'Martin Sheen, Marlon Brando, Robert Duvall, Frederic Forrest', 'Votes': 614385, 'Gross($M)': 83.47}
# 77 {'Movie_ID': 77, 'Title': 'Alien', 'Certificate': '12', 'Duration': 117, 'Genre': 'Horror, Sci-Fi', 'Rate': 8.4, 'Metascore': 89, 'Description': 'After a space merchant vessel receives an unknown transmission as a distress call, one of the crew is attacked by a mysterious life form and they soon realize that its life cycle has merely begun.', 'Year': 1979, 'Directors': 'Ridley Scott', 'Stars': 'Sigourney Weaver, Tom Skerritt, John Hurt, Veronica Cartwright', 'Votes': 798472, 'Gross($M)': 78.9}
# 78 {'Movie_ID': 78, 'Title': 'Tengoku to jigoku', 'Certificate': '12', 'Duration': 143, 'Genre': 'Crime, Drama, Mystery', 'Rate': 8.4, 'Metascore': 0, 'Description': "An executive of a shoe company becomes a victim of extortion when his chauffeur's son is kidnapped and held for ransom.", 'Year': 1963, 'Directors': 'Akira Kurosawa', 'Stars': 'Toshirô Mifune, Yutaka Sada, Tatsuya Nakadai, Kyôko Kagawa', 'Votes': 35992, 'Gross($M)': 0.0}
# 79 {'Movie_ID': 79, 'Title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'Certificate': 'AL', 'Duration': 95, 'Genre': 'Comedy', 'Rate': 8.4, 'Metascore': 97, 'Description': 'An insane general triggers a path to nuclear holocaust that a War Room full of politicians and generals frantically tries to stop.', 'Year': 1964, 'Directors': 'Stanley Kubrick', 'Stars': 'Peter Sellers, George C. Scott, Sterling Hayden, Keenan Wynn', 'Votes': 455507, 'Gross($M)': 0.28}
# 80 {'Movie_ID': 80, 'Title': 'Witness for the Prosecution', 'Certificate': '14', 'Duration': 116, 'Genre': 'Crime, Drama, Mystery', 'Rate': 8.4, 'Metascore': 0, 'Description': 'A veteran British barrister must defend his client in a murder trial that has surprise after surprise.', 'Year': 1957, 'Directors': 'Billy Wilder', 'Stars': 'Tyrone Power, Marlene Dietrich, Charles Laughton, Elsa Lanchester', 'Votes': 111029, 'Gross($M)': 8.18}
# 81 {'Movie_ID': 81, 'Title': 'Paths of Glory', 'Certificate': '12', 'Duration': 88, 'Genre': 'Drama, War', 'Rate': 8.4, 'Metascore': 90, 'Description': 'After refusing to attack an enemy position, a general accuses the soldiers of cowardice and their commanding officer must defend them.', 'Year': 1957, 'Directors': 'Stanley Kubrick', 'Stars': 'Kirk Douglas, Ralph Meeker, Adolphe Menjou, George Macready', 'Votes': 181010, 'Gross($M)': 0.0}
# 82 {'Movie_ID': 82, 'Title': 'Rear Window', 'Certificate': '6', 'Duration': 112, 'Genre': 'Mystery, Thriller', 'Rate': 8.4, 'Metascore': 100, 'Description': 'A wheelchair-bound photographer spies on his neighbors from his apartment window and becomes convinced one of them has committed murder.', 'Year': 1954, 'Directors': 'Alfred Hitchcock', 'Stars': 'James Stewart, Grace Kelly, Wendell Corey, Thelma Ritter', 'Votes': 449646, 'Gross($M)': 36.76}
# 83 {'Movie_ID': 83, 'Title': 'Sunset Blvd.', 'Certificate': '18', 'Duration': 110, 'Genre': 'Drama, Film-Noir', 'Rate': 8.4, 'Metascore': 0, 'Description': 'A screenwriter develops a dangerous relationship with a faded film star determined to make a triumphant return.', 'Year': 1950, 'Directors': 'Billy Wilder', 'Stars': 'William Holden, Gloria Swanson, Erich von Stroheim, Nancy Olson', 'Votes': 204310, 'Gross($M)': 0.0}
# 84 {'Movie_ID': 84, 'Title': 'The Great Dictator', 'Certificate': '14', 'Duration': 125, 'Genre': 'Comedy, Drama, War', 'Rate': 8.4, 'Metascore': 0, 'Description': "Dictator Adenoid Hynkel tries to expand his empire while a poor Jewish barber tries to avoid persecution from Hynkel's regime.", 'Year': 1940, 'Directors': 'Charles Chaplin', 'Stars': 'Charles Chaplin, Paulette Goddard, Jack Oakie, Reginald Gardiner', 'Votes': 205829, 'Gross($M)': 0.29}
# 85 {'Movie_ID': 85, 'Title': '1917', 'Certificate': '12', 'Duration': 119, 'Genre': 'Drama, Thriller, War', 'Rate': 8.3, 'Metascore': 78, 'Description': 'April 6th, 1917. As a regiment assembles to wage war deep in enemy territory, two soldiers are assigned to race against time and deliver a message that will stop 1,600 men from walking straight into a deadly trap.', 'Year': 1917, 'Directors': 'Sam Mendes', 'Stars': 'Dean-Charles Chapman, George MacKay, Daniel Mays, Colin Firth', 'Votes': 451546, 'Gross($M)': 159.23}
# 86 {'Movie_ID': 86, 'Title': 'Tumbbad', 'Certificate': 'None', 'Duration': 104, 'Genre': 'Drama, Fantasy, Horror', 'Rate': 8.3, 'Metascore': 0, 'Description': 'A mythological story about a goddess who created the entire universe. The plot revolves around the consequences when humans build a temple for her first-born.', 'Year': 2018, 'Directors': 'Rahi Anil Barve, Anand Gandhi, Adesh Prasad', 'Stars': 'Sohum Shah, Jyoti Malshe, Anita Date, Ronjini Chakraborty', 'Votes': 29375, 'Gross($M)': 0.0}
# 87 {'Movie_ID': 87, 'Title': 'Drishyam', 'Certificate': 'None', 'Duration': 160, 'Genre': 'Crime, Drama, Thriller', 'Rate': 8.3, 'Metascore': 0, 'Description': 'A man goes to extreme lengths to save his family from punishment after the family commits an accidental crime.', 'Year': 2013, 'Directors': 'Jeethu Joseph', 'Stars': 'Mohanlal, Meena, Asha Sharath, Ansiba', 'Votes': 34482, 'Gross($M)': 0.0}
# 88 {'Movie_ID': 88, 'Title': 'Jagten', 'Certificate': '15+', 'Duration': 115, 'Genre': 'Drama', 'Rate': 8.3, 'Metascore': 77, 'Description': "A teacher lives a lonely life, all the while struggling over his son's custody. His life slowly gets better as he finds love and receives good news from his son, but his new luck is about to be brutally shattered by an innocent little lie.", 'Year': 2012, 'Directors': 'Thomas Vinterberg', 'Stars': 'Mads Mikkelsen, Thomas Bo Larsen, Annika Wedderkopp, Lasse Fogelstr', 'Votes': 289036, 'Gross($M)': 0.69}
# 89 {'Movie_ID': 89, 'Title': 'Jodaeiye Nader az Simin', 'Certificate': '6', 'Duration': 123, 'Genre': 'Drama', 'Rate': 8.3, 'Metascore': 95, 'Description': "A married couple are faced with a difficult decision - to improve the life of their child by moving to another country or to stay in Iran and look after a deteriorating parent who has Alzheimer's disease.", 'Year': 2011, 'Directors': 'Asghar Farhadi', 'Stars': 'Payman Maadi, Leila Hatami, Sareh Bayat, Shahab Hosseini', 'Votes': 223652, 'Gross($M)': 7.1}
# 90 {'Movie_ID': 90, 'Title': 'Incendies', 'Certificate': '16', 'Duration': 131, 'Genre': 'Drama, Mystery, War', 'Rate': 8.3, 'Metascore': 80, 'Description': "Twins journey to the Middle East to discover their family history and fulfill their mother's last wishes.", 'Year': 2010, 'Directors': 'Denis Villeneuve', 'Stars': 'Lubna Azabal, Mélissa Désormeaux-Poulin, Maxim Gaudette, Mustafa Kamel', 'Votes': 153872, 'Gross($M)': 6.86}
# 91 {'Movie_ID': 91, 'Title': 'Dara iz Jasenovca', 'Certificate': 'R', 'Duration': 130, 'Genre': 'Drama, War', 'Rate': 8.3, 'Metascore': 0, 'Description': 'Follows the story of a young girl named Dara who is sent to a concentration camp in Croatia during World War 2.', 'Year': 2020, 'Directors': 'Predrag Antonijevic', 'Stars': 'Biljana Cekic, Zlatan Vidovic, Anja Stanic, Luka Saranovic', 'Votes': 34229, 'Gross($M)': 0.0}
# 92 {'Movie_ID': 92, 'Title': 'The Father', 'Certificate': 'PG-13', 'Duration': 97, 'Genre': 'Drama', 'Rate': 8.3, 'Metascore': 88, 'Description': 'A man refuses all assistance from his daughter as he ages. As he tries to make sense of his changing circumstances, he begins to doubt his loved ones, his own mind and even the fabric of his reality.', 'Year': 2020, 'Directors': 'Florian Zeller', 'Stars': 'Anthony Hopkins, Olivia Colman, Mark Gatiss, Olivia Williams', 'Votes': 30879, 'Gross($M)': 0.0}
# 93 {'Movie_ID': 93, 'Title': 'Babam ve Oglum', 'Certificate': 'None', 'Duration': 108, 'Genre': 'Drama, Family', 'Rate': 8.3, 'Metascore': 0, 'Description': 'The family of a left-wing journalist is torn apart after the military coup of Turkey in 1980.', 'Year': 2005, 'Directors': 'Çagan Irmak', 'Stars': 'Eser Sariyar, Çetin Tekindor, Fikret Kuskan, Hümeyra', 'Votes': 80317, 'Gross($M)': 0.0}
# 94 {'Movie_ID': 94, 'Title': 'Inglourious Basterds', 'Certificate': '15+', 'Duration': 153, 'Genre': 'Adventure, Drama, War', 'Rate': 8.3, 'Metascore': 69, 'Description': "In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.", 'Year': 2009, 'Directors': 'Quentin Tarantino', 'Stars': 'Brad Pitt, Diane Kruger, Eli Roth, Mélanie Laurent', 'Votes': 1289063, 'Gross($M)': 120.54}
# 95 {'Movie_ID': 95, 'Title': 'Eternal Sunshine of the Spotless Mind', 'Certificate': 'AL', 'Duration': 108, 'Genre': 'Drama, Romance, Sci-Fi', 'Rate': 8.3, 'Metascore': 89, 'Description': 'When their relationship turns sour, a couple undergoes a medical procedure to have each other erased from their memories.', 'Year': 2004, 'Directors': 'Michel Gondry', 'Stars': 'Jim Carrey, Kate Winslet, Tom Wilkinson, Gerry Robert Byrne', 'Votes': 922515, 'Gross($M)': 34.4}
# 96 {'Movie_ID': 96, 'Title': 'AmÃ©lie', 'Certificate': 'AL', 'Duration': 122, 'Genre': 'Comedy, Romance', 'Rate': 8.3, 'Metascore': 69, 'Description': 'Amélie is an innocent and naive girl in Paris with her own sense of justice. She decides to help those around her and, along the way, discovers love.', 'Year': 2001, 'Directors': 'Jean-Pierre Jeunet', 'Stars': 'Audrey Tautou, Mathieu Kassovitz, Rufus, Lorella Cravotta', 'Votes': 710832, 'Gross($M)': 33.23}
# 97 {'Movie_ID': 97, 'Title': 'Snatch', 'Certificate': '16', 'Duration': 104, 'Genre': 'Comedy, Crime', 'Rate': 8.3, 'Metascore': 0, 'Description': 'Unscrupulous boxing promoters, violent bookmakers, a Russian gangster, incompetent amateur robbers and supposedly Jewish jewelers fight to track down a priceless stolen diamond.', 'Year': 2000, 'Directors': 'Guy Ritchie', 'Stars': 'Jason Statham, Brad Pitt, Benicio Del Toro, Dennis Farina', 'Votes': 790802, 'Gross($M)': 30.33}
# 98 {'Movie_ID': 98, 'Title': 'Requiem for a Dream', 'Certificate': '18+', 'Duration': 102, 'Genre': 'Drama', 'Rate': 8.3, 'Metascore': 68, 'Description': 'The drug-induced utopias of four Coney Island people are shattered when their addictions run deep.', 'Year': 2000, 'Directors': 'Darren Aronofsky', 'Stars': 'Ellen Burstyn, Jared Leto, Jennifer Connelly, Marlon Wayans', 'Votes': 776487, 'Gross($M)': 3.64}
# 99 {'Movie_ID': 99, 'Title': 'American Beauty', 'Certificate': '18+', 'Duration': 122, 'Genre': 'Drama', 'Rate': 8.3, 'Metascore': 84, 'Description': "A sexually frustrated suburban father has a mid-life crisis after becoming infatuated with his daughter's best friend.", 'Year': 1999, 'Directors': 'Sam Mendes', 'Stars': 'Kevin Spacey, Annette Bening, Thora Birch, Wes Bentley', 'Votes': 1080546, 'Gross($M)': 130.1}
# 100 {'Movie_ID': 100, 'Title': 'Good Will Hunting', 'Certificate': '12', 'Duration': 126, 'Genre': 'Drama, Romance', 'Rate': 8.3, 'Metascore': 70, 'Description': 'Will Hunting, a janitor at M.I.T., has a gift for mathematics, but needs help from a psychologist to find direction in his life.', 'Year': 1997, 'Directors': 'Gus Van Sant', 'Stars': 'Robin Williams, Matt Damon, Ben Affleck, Stellan Skarsg', 'Votes': 874312, 'Gross($M)': 138.43}
# ...
# 967 {'Movie_ID': 967, 'Title': 'Die Hard: With a Vengeance', 'Certificate': '16', 'Duration': 128, 'Genre': 'Action, Adventure, Thriller', 'Rate': 7.6, 'Metascore': 0, 'Description': 'John McClane and a Harlem store owner are targeted by German terrorist Simon in New York City, where he plans to rob the Federal Reserve Building.', 'Year': 1995, 'Directors': 'John McTiernan', 'Stars': 'Bruce Willis, Jeremy Irons, Samuel L. Jackson, Graham Greene', 'Votes': 366971, 'Gross($M)': 100.01}
# 968 {'Movie_ID': 968, 'Title': 'Dead Man', 'Certificate': '12', 'Duration': 121, 'Genre': 'Adventure, Drama, Fantasy', 'Rate': 7.6, 'Metascore': 62, 'Description': 'On the run after murdering a man, accountant William Blake encounters a strange aboriginal American man named Nobody who prepares him for his journey into the spiritual world.', 'Year': 1995, 'Directors': 'Jim Jarmusch', 'Stars': 'Johnny Depp, Gary Farmer, Crispin Glover, Lance Henriksen', 'Votes': 91356, 'Gross($M)': 1.04}
# 969 {'Movie_ID': 969, 'Title': 'The Bridges of Madison County', 'Certificate': 'AL', 'Duration': 135, 'Genre': 'Drama, Romance', 'Rate': 7.6, 'Metascore': 69, 'Description': 'Photographer Robert Kincaid wanders into the life of housewife Francesca Johnson for four days in the 1960s.', 'Year': 1995, 'Directors': 'Clint Eastwood', 'Stars': 'Clint Eastwood, Meryl Streep, Annie Corley, Victor Slezak', 'Votes': 74252, 'Gross($M)': 71.52}
# 970 {'Movie_ID': 970, 'Title': 'Apollo 13', 'Certificate': 'AL', 'Duration': 140, 'Genre': 'Adventure, Drama, History', 'Rate': 7.6, 'Metascore': 77, 'Description': 'NASA must devise a strategy to return Apollo 13 to Earth safely after the spacecraft undergoes massive internal damage putting the lives of the three astronauts on board in jeopardy.', 'Year': 1995, 'Directors': 'Ron Howard', 'Stars': 'Tom Hanks, Bill Paxton, Kevin Bacon, Gary Sinise', 'Votes': 273116, 'Gross($M)': 173.84}
# 971 {'Movie_ID': 971, 'Title': 'Trois couleurs: Blanc', 'Certificate': '12', 'Duration': 92, 'Genre': 'Comedy, Drama, Romance', 'Rate': 7.6, 'Metascore': 88, 'Description': 'After his wife divorces him, a Polish immigrant plots to get even with her.', 'Year': 1994, 'Directors': 'Krzysztof Kieslowski', 'Stars': 'Zbigniew Zamachowski, Julie Delpy, Janusz Gajos, Jerzy Stuhr', 'Votes': 65788, 'Gross($M)': 1.46}
# 972 {'Movie_ID': 972, 'Title': 'Falling Down', 'Certificate': '16', 'Duration': 113, 'Genre': 'Crime, Drama, Thriller', 'Rate': 7.6, 'Metascore': 0, 'Description': 'An ordinary man frustrated with the various flaws he sees in society begins to psychotically and violently lash out against them.', 'Year': 1993, 'Directors': 'Joel Schumacher', 'Stars': 'Michael Douglas, Robert Duvall, Barbara Hershey, Rachel Ticotin', 'Votes': 174127, 'Gross($M)': 40.9}
# 973 {'Movie_ID': 973, 'Title': 'Dazed and Confused', 'Certificate': '12', 'Duration': 102, 'Genre': 'Comedy', 'Rate': 7.6, 'Metascore': 78, 'Description': 'The adventures of high school and junior high students on the last day of school in May 1976.', 'Year': 1993, 'Directors': 'Richard Linklater', 'Stars': 'Jason London, Wiley Wiggins, Matthew McConaughey, Rory Cochrane', 'Votes': 168526, 'Gross($M)': 7.99}
# 974 {'Movie_ID': 974, 'Title': 'My Cousin Vinny', 'Certificate': 'AL', 'Duration': 120, 'Genre': 'Comedy, Crime', 'Rate': 7.6, 'Metascore': 68, 'Description': 'Two New Yorkers accused of murder in rural Alabama while on their way back to college call in the help of one of their cousins, a loudmouth lawyer with no trial experience.', 'Year': 1992, 'Directors': 'Jonathan Lynn', 'Stars': 'Joe Pesci, Marisa Tomei, Ralph Macchio, Mitchell Whitfield', 'Votes': 109226, 'Gross($M)': 52.93}
# 975 {'Movie_ID': 975, 'Title': 'Kal Hee', 'Certificate': 'PG', 'Duration': 118, 'Genre': 'Animation, Drama, Romance', 'Rate': 7.6, 'Metascore': 90, 'Description': 'A twenty-seven-year-old office worker travels to the countryside while reminiscing about her childhood in Tokyo.', 'Year': 1991, 'Directors': 'Isao Takahata', 'Stars': 'Miki Imai, Toshirô Yanagiba, Yoko Honna, Mayumi Izuka', 'Votes': 27907, 'Gross($M)': 0.45}
# 976 {'Movie_ID': 976, 'Title': 'Home Alone', 'Certificate': 'G', 'Duration': 103, 'Genre': 'Comedy, Family', 'Rate': 7.6, 'Metascore': 63, 'Description': 'An eight-year-old troublemaker must protect his house from a pair of burglars when he is accidentally left home alone by his family during Christmas vacation.', 'Year': 1990, 'Directors': 'Chris Columbus', 'Stars': 'Macaulay Culkin, Joe Pesci, Daniel Stern, John Heard', 'Votes': 494129, 'Gross($M)': 285.76}
# 977 {'Movie_ID': 977, 'Title': 'The Godfather: Part III', 'Certificate': '16', 'Duration': 162, 'Genre': 'Crime, Drama', 'Rate': 7.6, 'Metascore': 0, 'Description': 'Follows Michael Corleone, now in his 60s, as he seeks to free his family from crime and find a suitable successor to his empire.', 'Year': 1990, 'Directors': 'Francis Ford Coppola', 'Stars': 'Al Pacino, Diane Keaton, Andy Garcia, Talia Shire', 'Votes': 365298, 'Gross($M)': 66.67}
# 978 {'Movie_ID': 978, 'Title': 'When Harry Met Sally...', 'Certificate': 'AL', 'Duration': 95, 'Genre': 'Comedy, Drama, Romance', 'Rate': 7.6, 'Metascore': 76, 'Description': 'Harry and Sally have known each other for years, and are very good friends, but they fear sex would ruin the friendship.', 'Year': 1989, 'Directors': 'Rob Reiner', 'Stars': 'Billy Crystal, Meg Ryan, Carrie Fisher, Bruno Kirby', 'Votes': 198282, 'Gross($M)': 92.82}
# 979 {'Movie_ID': 979, 'Title': 'The Little Mermaid', 'Certificate': 'AL', 'Duration': 83, 'Genre': 'Animation, Family, Fantasy', 'Rate': 7.6, 'Metascore': 88, 'Description': "A mermaid princess makes a Faustian bargain in an attempt to become human and win a prince's love.", 'Year': 1989, 'Directors': 'Ron Clements, John Musker', 'Stars': 'Jodi Benson, Samuel E. Wright, Rene Auberjonois, Christopher Daniel Barnes', 'Votes': 240543, 'Gross($M)': 111.54}
# 980 {'Movie_ID': 980, 'Title': 'The Naked Gun: From the Files of Police Squad!', 'Certificate': 'AL', 'Duration': 85, 'Genre': 'Comedy, Crime', 'Rate': 7.6, 'Metascore': 76, 'Description': 'Incompetent police Detective Frank Drebin must foil an attempt to assassinate Queen Elizabeth II.', 'Year': 1988, 'Directors': 'David Zucker', 'Stars': 'Leslie Nielsen, Priscilla Presley, O.J. Simpson, Ricardo Montalban', 'Votes': 154995, 'Gross($M)': 78.76}
# 981 {'Movie_ID': 981, 'Title': 'Planes', 'Certificate': 'AL', 'Duration': 93, 'Genre': 'Comedy, Drama', 'Rate': 7.6, 'Metascore': 72, 'Description': 'A man must struggle to travel home for Thanksgiving with a lovable oaf of a shower curtain ring salesman as his only companion.', 'Year': 1987, 'Directors': 'John Hughes', 'Stars': 'Steve Martin, John Candy, Laila Robins, Michael McKean', 'Votes': 126117, 'Gross($M)': 49.53}
# 982 {'Movie_ID': 982, 'Title': 'Lethal Weapon', 'Certificate': '16', 'Duration': 109, 'Genre': 'Action, Crime, Thriller', 'Rate': 7.6, 'Metascore': 68, 'Description': 'Two newly paired cops who are complete opposites must put aside their differences in order to catch a gang of drug smugglers.', 'Year': 1987, 'Directors': 'Richard Donner', 'Stars': 'Mel Gibson, Danny Glover, Gary Busey, Mitchell Ryan', 'Votes': 239236, 'Gross($M)': 65.21}
# 983 {'Movie_ID': 983, 'Title': 'Blood Simple', 'Certificate': '16', 'Duration': 99, 'Genre': 'Crime, Drama, Thriller', 'Rate': 7.6, 'Metascore': 83, 'Description': 'The owner of a seedy small-town Texas bar discovers that one of his employees is having an affair with his wife. A chaotic chain of misunderstandings, lies and mischief ensues after he devises a plot to have them murdered.', 'Year': 1984, 'Directors': 'Joel Coen, Ethan Coen', 'Stars': 'John Getz, Frances McDormand, Dan Hedaya, M. Emmet Walsh', 'Votes': 89219, 'Gross($M)': 2.15}
# 984 {'Movie_ID': 984, 'Title': 'On Golden Pond', 'Certificate': 'AL', 'Duration': 109, 'Genre': 'Drama', 'Rate': 7.6, 'Metascore': 68, 'Description': "Norman is a curmudgeon with an estranged relationship with his daughter Chelsea. At Golden Pond, he and his wife nevertheless agree to care for Billy, the son of Chelsea's new boyfriend, and a most unexpected relationship blooms.", 'Year': 1981, 'Directors': 'Mark Rydell', 'Stars': 'Katharine Hepburn, Henry Fonda, Jane Fonda, Doug McKeon', 'Votes': 28036, 'Gross($M)': 119.29}
# 985 {'Movie_ID': 985, 'Title': 'Mad Max 2', 'Certificate': '16', 'Duration': 96, 'Genre': 'Action, Adventure, Sci-Fi', 'Rate': 7.6, 'Metascore': 77, 'Description': 'In the post-apocalyptic Australian wasteland, a cynical drifter agrees to help a small, gasoline-rich community escape a horde of bandits.', 'Year': 1981, 'Directors': 'George Miller', 'Stars': 'Mel Gibson, Bruce Spence, Michael Preston, Max Phipps', 'Votes': 168128, 'Gross($M)': 12.47}
# 986 {'Movie_ID': 986, 'Title': 'The Warriors', 'Certificate': '15A', 'Duration': 92, 'Genre': 'Action, Crime, Thriller', 'Rate': 7.6, 'Metascore': 65, 'Description': 'In the near future, a charismatic leader summons the street gangs of New York City in a bid to take it over. When he is killed, The Warriors are falsely blamed and now must fight their way home while every other gang is hunting them down.', 'Year': 1979, 'Directors': 'Walter Hill', 'Stars': 'Michael Beck, James Remar, Dorsey Wright, Brian Tyler', 'Votes': 95025, 'Gross($M)': 22.49}
# 987 {'Movie_ID': 987, 'Title': 'The Muppet Movie', 'Certificate': 'None', 'Duration': 95, 'Genre': 'Adventure, Comedy, Family', 'Rate': 7.6, 'Metascore': 74, 'Description': 'Kermit and his newfound friends trek across America to find success in Hollywood, but a frog legs merchant is after Kermit.', 'Year': 1979, 'Directors': 'James Frawley', 'Stars': 'Jim Henson, Frank Oz, Jerry Nelson, Richard Hunt', 'Votes': 33241, 'Gross($M)': 76.66}
# 988 {'Movie_ID': 988, 'Title': 'Escape from Alcatraz', 'Certificate': '12', 'Duration': 112, 'Genre': 'Action, Biography, Crime', 'Rate': 7.6, 'Metascore': 76, 'Description': 'Alcatraz is the most secure prison of its time. It is believed that no one can ever escape from it, until three daring men make a possible successful attempt at escaping from one of the most infamous prisons in the world.', 'Year': 1979, 'Directors': 'Don Siegel', 'Stars': 'Clint Eastwood, Patrick McGoohan, Roberts Blossom, Jack Thibeau', 'Votes': 123467, 'Gross($M)': 43.0}
# 989 {'Movie_ID': 989, 'Title': 'Watership Down', 'Certificate': '9', 'Duration': 91, 'Genre': 'Animation, Adventure, Drama', 'Rate': 7.6, 'Metascore': 64, 'Description': 'Hoping to escape destruction by human developers and save their community, a colony of rabbits, led by Hazel and Fiver, seek out a safe place to set up a new warren.', 'Year': 1978, 'Directors': 'Martin Rosen, John Hubley', 'Stars': 'John Hurt, Richard Briers, Ralph Richardson, Michael Graham Cox', 'Votes': 34054, 'Gross($M)': 0.0}
# 990 {'Movie_ID': 990, 'Title': 'Close Encounters of the Third Kind', 'Certificate': 'G', 'Duration': 138, 'Genre': 'Drama, Sci-Fi', 'Rate': 7.6, 'Metascore': 90, 'Description': 'Roy Neary, an electric lineman, watches how his quiet and ordinary daily life turns upside down after a close encounter with a UFO.', 'Year': 1977, 'Directors': 'Steven Spielberg', 'Stars': 'Richard Dreyfuss, François Truffaut, Teri Garr, Melinda Dillon', 'Votes': 187024, 'Gross($M)': 132.09}
# 991 {'Movie_ID': 991, 'Title': 'The Long Goodbye', 'Certificate': '18', 'Duration': 112, 'Genre': 'Comedy, Crime, Drama', 'Rate': 7.6, 'Metascore': 87, 'Description': "Private investigator Philip Marlowe helps a friend out of a jam, but in doing so gets implicated in his wife's murder.", 'Year': 1973, 'Directors': 'Robert Altman', 'Stars': 'Elliott Gould, Nina van Pallandt, Sterling Hayden, Mark Rydell', 'Votes': 26801, 'Gross($M)': 0.96}
# 992 {'Movie_ID': 992, 'Title': 'GiÃ¹ la testa', 'Certificate': '18', 'Duration': 157, 'Genre': 'Drama, War, Western', 'Rate': 7.6, 'Metascore': 77, 'Description': 'A low-life bandit and an I.R.A. explosives expert rebel against the government and become heroes of the Mexican Revolution.', 'Year': 1971, 'Directors': 'Sergio Leone', 'Stars': 'Rod Steiger, James Coburn, Romolo Valli, Maria Monti', 'Votes': 30590, 'Gross($M)': 0.7}
# 993 {'Movie_ID': 993, 'Title': "Kelly's Heroes", 'Certificate': '14', 'Duration': 144, 'Genre': 'Adventure, Comedy, War', 'Rate': 7.6, 'Metascore': 0, 'Description': 'A group of U.S. soldiers sneaks across enemy lines to get their hands on a secret stash of Nazi treasure.', 'Year': 1970, 'Directors': 'Brian G. Hutton', 'Stars': "Clint Eastwood, Telly Savalas, Don Rickles, Carroll O'Connor", 'Votes': 45753, 'Gross($M)': 1.38}
# 994 {'Movie_ID': 994, 'Title': 'The Jungle Book', 'Certificate': 'AL', 'Duration': 78, 'Genre': 'Animation, Adventure, Family', 'Rate': 7.6, 'Metascore': 65, 'Description': 'Bagheera the Panther and Baloo the Bear have a difficult time trying to convince a boy to leave the jungle for human civilization.', 'Year': 1967, 'Directors': 'Wolfgang Reitherman', 'Stars': 'Phil Harris, Sebastian Cabot, Louis Prima, Bruce Reitherman', 'Votes': 168226, 'Gross($M)': 141.84}
# 995 {'Movie_ID': 995, 'Title': "A Hard Day's Night", 'Certificate': 'AL', 'Duration': 87, 'Genre': 'Comedy, Musical', 'Rate': 7.6, 'Metascore': 96, 'Description': 'Over two "typical" days in the life of The Beatles, the boys struggle to keep themselves and Sir Paul McCartney\'s mischievous grandfather in check while preparing for a live television performance.', 'Year': 1964, 'Directors': 'Richard Lester', 'Stars': 'John Lennon, Paul McCartney, George Harrison, Ringo Starr', 'Votes': 40732, 'Gross($M)': 13.78}
# 996 {'Movie_ID': 996, 'Title': "Breakfast at Tiffany's", 'Certificate': 'AL', 'Duration': 115, 'Genre': 'Comedy, Drama, Romance', 'Rate': 7.6, 'Metascore': 76, 'Description': 'A young New York socialite becomes interested in a young man who has moved into her apartment building, but her past threatens to get in the way.', 'Year': 1961, 'Directors': 'Blake Edwards', 'Stars': 'Audrey Hepburn, George Peppard, Patricia Neal, Buddy Ebsen', 'Votes': 168708, 'Gross($M)': 0.0}
# 997 {'Movie_ID': 997, 'Title': 'Giant', 'Certificate': 'G', 'Duration': 201, 'Genre': 'Drama, Western', 'Rate': 7.6, 'Metascore': 84, 'Description': 'Sprawling epic covering the life of a Texas cattle rancher and his family and associates.', 'Year': 1956, 'Directors': 'George Stevens', 'Stars': 'Elizabeth Taylor, Rock Hudson, James Dean, Carroll Baker', 'Votes': 34593, 'Gross($M)': 0.0}
# 998 {'Movie_ID': 998, 'Title': 'From Here to Eternity', 'Certificate': '12', 'Duration': 118, 'Genre': 'Drama, Romance, War', 'Rate': 7.6, 'Metascore': 85, 'Description': "In Hawaii in 1941, a private is cruelly punished for not boxing on his unit's team, while his captain's wife and second-in-command are falling in love.", 'Year': 1953, 'Directors': 'Fred Zinnemann', 'Stars': 'Burt Lancaster, Montgomery Clift, Deborah Kerr, Donna Reed', 'Votes': 43867, 'Gross($M)': 30.5}
# 999 {'Movie_ID': 999, 'Title': 'Lifeboat', 'Certificate': 'None', 'Duration': 97, 'Genre': 'Drama, War', 'Rate': 7.6, 'Metascore': 78, 'Description': 'Several survivors of a torpedoed merchant ship in World War II find themselves in the same lifeboat with one of the crew members of the U-boat that sank their ship.', 'Year': 1944, 'Directors': 'Alfred Hitchcock', 'Stars': 'Tallulah Bankhead, John Hodiak, Walter Slezak, William Bendix', 'Votes': 26791, 'Gross($M)': 0.0}
# 1000 {'Movie_ID': 1000, 'Title': 'The 39 Steps', 'Certificate': '14', 'Duration': 86, 'Genre': 'Crime, Mystery, Thriller', 'Rate': 7.6, 'Metascore': 93, 'Description': 'A man in London tries to help a counter-espionage Agent. But when the Agent is killed, and the man stands accused, he must go on the run to save himself and stop a spy ring which is trying to steal top secret information.', 'Year': 1935, 'Directors': 'Alfred Hitchcock', 'Stars': 'Robert Donat, Madeleine Carroll, Lucie Mannheim, Godfrey Tearle', 'Votes': 52686, 'Gross($M)': 0.0}

# %%
#crs.execute("INSERT TestA (FirstName, LastName) VALUES (?,?)",'Bruce', 'Lee')

# %%
sql = 'INSERT imdb VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?)'

# %%
for k,v in enumerate(records, start = 1):
    crs.execute(sql, (k, v['Title'], v['Certificate'], v['Duration'], v['Genre'], v['Rate'], v['Metascore'],v['Description'], v['Year'], v['Directors'], v['Stars'], v['Votes'], v['Gross($M)']))

# %% [markdown]
# **4- With Python and related sql queries from the database:**
#
# <br>- Find number of movies
# <br>- Find the highest rated movie
# <br>- Find the second highest rated movie
# <br>- Find the number of movies produced before 2000
# <br>- Find the average gross of the movies by years.
# <br>- Find the total number of movies by years.
# <br>- Draw the frequency graph of the film ratings.
# <br>- Find the top 10 movies with the highest gross and visualize them with a bar chart.
# <br>- Find the total groos of the movies directed Peter Jackson.
# <br>- Find the most popular star & most popular director and the number of movies they have included

# %%
df1= pd.read_sql("select top 10 * from imdb;", con = conn)

# %%
df1
# Out:
#    Movie_ID                                          Title Certificate  \
# 0         1                       The Shawshank Redemption         13+
# 1         2                                  The Godfather          16
# 2         3                                The Dark Knight          16
# 3         4                         The Godfather: Part II          12
# 4         5                                   12 Angry Men          14
# 5         6  The Lord of the Rings: The Return of the King          12
# 6         7                                   Pulp Fiction         18+
# 7         8                               Schindler's List          12
# 8         9                                      Inception         13+
# 9        10                                     Fight Club         18+
#
#    Duration                      Genre  Rate  Metascore  \
# 0       142                      Drama   9.3         80
# 1       175               Crime, Drama   9.2        100
# 2       152       Action, Crime, Drama   9.0         84
# 3       202               Crime, Drama   9.0         90
# 4        96               Crime, Drama   9.0         96
# 5       201   Action, Adventure, Drama   8.9         94
# 6       154               Crime, Drama   8.9         94
# 7       195  Biography, Drama, History   8.9         94
# 8       148  Action, Adventure, Sci-Fi   8.8         74
# 9       139                      Drama   8.8         66
#
#                                          Description  Year  \
# 0  Two imprisoned men bond over a number of years...  1994
# 1  An organized crime dynasty's aging patriarch t...  1972
# 2  When the menace known as the Joker wreaks havo...  2008
# 3  The early life and career of Vito Corleone in ...  1974
# 4  A jury holdout attempts to prevent a miscarria...  1957
# 5  Gandalf and Aragorn lead the World of Men agai...  2003
# 6  The lives of two mob hitmen, a boxer, a gangst...  1994
# 7  In German-occupied Poland during World War II,...  1993
# 8  A thief who steals corporate secrets through t...  2010
# 9  A nameless first person narrator (Edward Norto...  1999
#
#               Directors                                              Stars  \
# 0        Frank Darabont  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Francis Ford Coppola  Marlon Brando, Al Pacino, James Caan, Diane Ke...
# 2     Christopher Nolan  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 3  Francis Ford Coppola  Al Pacino, Robert De Niro, Robert Duvall, Dian...
# 4          Sidney Lumet  Henry Fonda, Lee J. Cobb, Martin Balsam, John ...
# 5         Peter Jackson  Elijah Wood, Viggo Mortensen, Ian McKellen, Or...
# 6     Quentin Tarantino  John Travolta, Uma Thurman, Samuel L. Jackson,...
# 7      Steven Spielberg  Liam Neeson, Ralph Fiennes, Ben Kingsley, Caro...
# 8     Christopher Nolan  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 9         David Fincher  Brad Pitt, Edward Norton, Meat Loaf, Zach Grenier
#
#      Votes   Gross
# 0  2377444   28.34
# 1  1646788  134.97
# 2  2341216  534.86
# 3  1146645   57.30
# 4   701877    4.36
# 5  1663885  377.85
# 6  1852167  107.93
# 7  1229532   96.90
# 8  2099808  292.58
# 9  1881308   37.03

# %%
# Find number of movies

query_1 = "SELECT COUNT(*) FROM imdb;"

crs.execute(query_1).fetchone()[0]
# Out:
# 1000

# %%
# --Find the highest rated movie
query_2 = "SELECT TOP 1 Title, Rate FROM imdb ORDER BY Rate DESC;"

crs.execute(query_2)
highest_rated = crs.fetchone()

# %%
highest_rated
# Out:
# ('The Shawshank Redemption', 9.3)

# %%
highest_rated[0]
# Out:
# 'The Shawshank Redemption'

# %%
highest_rated[1]
# Out:
# 9.3

# %%
print(f"Highest_rated_movie:{highest_rated[0]} ({highest_rated[1]} Rated)")
# Out:
# Highest_rated_movie:The Shawshank Redemption (9.3 Rated)

# %%
# --Find the second highest rated movie
query_3 = """SELECT * 
             FROM    (SELECT Title, Rate, ROW_NUMBER() OVER (ORDER BY Rate DESC) ROWNUM FROM imdb) A
             WHERE ROWNUM = 2
            """

crs.execute(query_3)
second_highest_rated = crs.fetchall()[0]
second_highest_rated_movie = f"{second_highest_rated[0]}({second_highest_rated[1]} Rated)"
print('second_highest_rated_movie:',second_highest_rated_movie)
# Out:
# second_highest_rated_movie: The Godfather(9.2 Rated)

# %%
# --Find the number of movies produced before 2000

query_4 ="SELECT COUNT(Movie_ID) FROM imdb WHERE Year<2000;"
crs.execute(query_4)
before_2000= crs.fetchall()[0][0]
print("the number of movies produced before 2000:",before_2000)
# Out:
# the number of movies produced before 2000: 513

# %%
crs.execute(query_4).fetchall()[0][0]
# Out:
# 513
