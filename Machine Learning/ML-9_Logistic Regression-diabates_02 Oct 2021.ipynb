# %% [markdown]
# # Logistic Regression

# %% [raw]
# https://veribilimcisi.com/2017/07/18/lojistik-regresyon/

# %% [raw]
# LOGISTIC REGRESSION NEDİR?
#
# Lojistik regresyon, bağımlı değişkenin kategorik bir değişken olduğu regresyon problemi gibidir. Lineer sınıflandırma problemlerinde yaygın bir biçimde kullanılır. Regresyon denilmesine rağmen burada bir sınıflandırma söz konusudur.
#
# Lojistik regresyon, bir sonucu belirleyen bir veya daha fazla bağımsız değişken bulunan bir veri kümesini analiz etmek için kullanılan istatistiksel bir yöntemdir. Sonuç, ikili bir değişkenle ölçülür (yalnızca iki olası sonuç vardır).
#
# Lojistik regresyonda, bağımlı değişken ikili veya ikili, yani yalnızca 1 (DOĞRU, başarı, hamile vb.) Veya 0 (YANLıŞ, hata, gebe olmayan vb.) Olarak kodlanmış verileri içeriyor.
#
# Lojistik regresyonun amacı,  iki yönlü karakteristiği (bağımlı değişken = yanıt veya sonuç değişkeni) ile ilgili bir dizi bağımsız (öngörücü veya açıklayıcı) değişken arasındaki ilişkiyi tanımlamak için en uygun (henüz biyolojik olarak makul) modeli bulmaktır.
#
# Detaylı bilgi için ML-9_Logistic Regression-MultiClass-iris_02Oct 2021'a bakınız.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
#%matplotlib notebook
plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df=pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0            6      148             72             35        0 33.600
# 1            1       85             66             29        0 26.600
# 2            8      183             64              0        0 23.300
# 3            1       89             66             23       94 28.100
# 4            0      137             40             35      168 43.100
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe().T
# Out:
#                            count    mean     std    min    25%     50%  \
# Pregnancies              768.000   3.845   3.370  0.000  1.000   3.000
# Glucose                  768.000 120.895  31.973  0.000 99.000 117.000
# BloodPressure            768.000  69.105  19.356  0.000 62.000  72.000
# SkinThickness            768.000  20.536  15.952  0.000  0.000  23.000
# Insulin                  768.000  79.799 115.244  0.000  0.000  30.500
# BMI                      768.000  31.993   7.884  0.000 27.300  32.000
# DiabetesPedigreeFunction 768.000   0.472   0.331  0.078  0.244   0.372
# Age                      768.000  33.241  11.760 21.000 24.000  29.000
# Outcome                  768.000   0.349   0.477  0.000  0.000   0.000
#
#                              75%     max
# Pregnancies                6.000  17.000
# Glucose                  140.250 199.000
# BloodPressure             80.000 122.000
# SkinThickness             32.000  99.000
# Insulin                  127.250 846.000
# ...

# %%
df.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [raw]
# data setindeki target labeldaki class'ların oranı arasında büyük fark varsa imbalance durumu ortaya çıkabilir. Ama kesinlikle imbalancetır diyemeyiz. Duruma göre bazen az datayla bile (karakteristiği belirgin olan siyahilerin vücut ölçüleri üzerinde çalışırkenki gibi) durumlarda balance durumu olabilir.
#
# datamıza baktığımızda 500 adet 0 değerine karşılık 268 adet 1 değeri mevcuttur. imbalance durumundan söz edebiliriz.

# %%
sns.countplot(df.Outcome)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %% [raw]
# boxplotlara bakarak 1.5 IQR değerine göre bu değerin altında kalan value ları tutacağım.

# %%
sns.boxplot(df.Pregnancies)
# Out:
# <AxesSubplot:xlabel='Pregnancies'>

# %%
df=df[df.Pregnancies<13]

# %%
sns.boxplot(df.Pregnancies)
# Out:
# <AxesSubplot:xlabel='Pregnancies'>

# %%
sns.boxplot(df.SkinThickness)
# Out:
# <AxesSubplot:xlabel='SkinThickness'>

# %%
df=df[df.SkinThickness<70]

# %%
sns.boxplot(df.SkinThickness)
# Out:
# <AxesSubplot:xlabel='SkinThickness'>

# %%
sns.boxplot(df.Insulin)

# zaten diabet hastalarında insulin değeri çok yüksek olur. bu yüzden bu yüksek değerleri outlier olarak değerlendirmiyoruz.
# Out:
# <AxesSubplot:xlabel='Insulin'>

# %%
sns.boxplot(df.Glucose)

# şeker düzeyi kimsede 0 olamaz bu yüzden 0 altında olanları almıyoruz.
# Out:
# <AxesSubplot:xlabel='Glucose'>

# %%
df=df[df.Glucose>0]

# glucose değeri 0 dan büyük olanları alıyoruz.

# %%
sns.boxplot(df.Glucose)
# Out:
# <AxesSubplot:xlabel='Glucose'>

# %%
sns.boxplot(df.BloodPressure)
# Out:
# <AxesSubplot:xlabel='BloodPressure'>

# %%
df=df[df.BloodPressure>35]

# %%
sns.boxplot(df.BloodPressure)
# Out:
# <AxesSubplot:xlabel='BloodPressure'>

# %%
sns.boxplot(df.BMI)

# vücut kitle indeksi
# Out:
# <AxesSubplot:xlabel='BMI'>

# %%
df=df[df.BMI>0]

# %%
sns.boxplot(df.BMI)
# Out:
# <AxesSubplot:xlabel='BMI'>

# %%
df.shape
# Out:
# (707, 9)

# %%
df.Outcome.value_counts()
# Out:
# 0    468
# 1    239
# Name: Outcome, dtype: int64

# %%
index = 0
plt.figure(figsize=(20,20))
for feature in df.columns:
    if feature != "Outcome":
        index += 1
        plt.subplot(3,3,index)
        sns.boxplot(x='Outcome',y=feature,data=df)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# df.corr()
# df.corr()["Outcome"].sort_values().plot.barh()
df.corr()["Outcome"].drop("Outcome").sort_values().plot.barh()

# diğer feature ların outcome (target) a göre corr larına bakıyoruz. 
# kendi ile corr'u 1 olacağı için ona bakmaya gerek yok.
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df, hue = "Outcome")

# %% [markdown]
# ## Train | Test Split and Scaling

# %%
X=df.drop(["Outcome"], axis=1)
y=df["Outcome"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)  # fit ve transformu beraber aynı kod ile yaptık.

X_test_scaled = scaler.transform(X_test)

# %% [raw]
# feature'larımın skalası ve birimleri birbirinden çok farklı ise bunları scale edip belli bir skalada eşitlemem gerekiyor.
# Kaldı ki benim target column'um binary (0 ve 1 lerden oluşuyor) olmasına rağmen featurelarım değişik değerlere sahip. bu durumda diğer feature larımı scale etmem şart.
#
# fit işlemi train datası içerisindeki verilerin hepsine bakıyor, tüm sütunlara tek tek bakıyor. seçtiğinizi scaler tipi ne ise (std, max, min.. her ne ise) o değerleri bir kenara yazıyor.
#
# Sonra transform dediğinizde fit ile aldığınız değerler üzerinden X_train datasını dönüştürüyor. (Zaten onu X_train_scaled diye ayrı bir değişkene atıyoruz ve öyle devam ediyoruz)
#
# Test datasının hiç bir referans noktasını, hiç bir bölümünü modelimin görmemesi gerekir. o yüzden test datasına hiç bir şekilde fit işlemini uygulamıyoruz. DOLAYISIYLA TEST DATAM FIT EDİLMİYOR, SADECE TRAIN DATAM ÜZERİNDEN EĞİTİLEN DEĞERLERLE SCALE'E TRANSFORM EDİLİYOR.
#
# Sonuç olarak train datamı hem (fit ile) eğitiyoruz hem de (transform ile) scale değerine dönüştürüyoruz.
# Fakat test datamı eğitmiyorum sadece dönüştürüyorum.

# %% [markdown]
# ## Modelling

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression(class_weight = "balanced")

# The "balanced" mode uses the values of y to automatically adjust weights inversely proportional to class frequencies in the input data

# 'balanced' mode, giriş verilerindeki sınıf frekanslarıyla ters orantılı ağırlıkları otomatik olarak ayarlamak için y değerlerini kullanır.

# %% [raw]
# imbalance bir data ile karşılaştığınızda "balanced" parametresini kullanmanız gerekir. balance ta da kullanabilirsin ama elzem değildir.
#
# balance, az olan target değerlerine daha fazla iltimas geçiyor. target değerinin ağırlığı ile ters orantılı olarak davranarak bu şekilde dengeyi sağlamaya çalışıyor.

# %% [raw]
# hayperparametreye göre bulacağımız coef ler değişir. sonuç olarak olasılıklar da değişir.

# %%
log_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred=log_model.predict(X_test_scaled)

# %%
y_pred_proba = log_model.predict_proba(X_test_scaled)

# %%
test_data = pd.concat([X_test, y_test], axis=1)  # test_data'yı geçici olarak kullancağım. amacım outcome ile predleri kıyaslamak.
test_data["pred"] = y_pred  # test_datama pred değerlerimi ekliyorum
test_data["pred_proba"] = y_pred_proba[:,1]   # proba değerlerimi ekliyorum. 1 olma olasılıklarını kullanacağım dolayısıyla listedik 2. elemanları aldım.
test_data.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 215           12      151             70             40      271 41.800
# 366            6      124             72              0        0 27.600
# 546            5      187             76             27      207 43.600
# 436           12      140             85             33        0 37.400
# 432            1       80             74             11       60 30.000
# 334            1       95             60             18       58 23.900
# 61             8      133             72              0        0 32.900
# 359            1      196             76             36      249 36.500
# 764            2      122             70             27        0 36.800
# 307            0      137             68             14      148 24.800
#
#      DiabetesPedigreeFunction  Age  Outcome  pred  pred_proba
# 215                     0.742   38        1     1       0.951
# ...

# %% [markdown]
# ## Model Performance on Classification Tasks

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %% [raw]
# 1 skorlarım 0 a göre düşük. neden? çünkü elimdeki datamda 1 değerleri daha az. bu yüzden öğrenmesi kötü olmuş. 0 ile ilgili daha fazla  soru çözmüş daha çok çalışmış o yüzden 0'ı daha iyi öğrenmiş ve sonuç olarak 0 değerleri daha yüksek.

# %%
# scores with "class_weight = "balanced"

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[93 32]
#  [13 39]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.74      0.81       125
#            1       0.55      0.75      0.63        52
#
#     accuracy                           0.75       177
#    macro avg       0.71      0.75      0.72       177
# weighted avg       0.78      0.75      0.75       177

# %% [raw]
# hasta olanlara sen hastasın demek önemli. Bu recall değeridir ( 1 olanların 1 olduğunu bilebilmek)
#
# hasta olmayan birine hastasın demek çok büyük problem yaratmaz ama hasta olan birinin hasta olmadığını bulmak o hastayı kaybettirir.
#
# classification_report()'u datamı balance yapmadan uyguladığımda accuracy değerimin 0.68 idi. balance parametresini kullandığımda bu değerin 0.75 e yükseldiğini gördüm.
#
# Dolayısıyla yukarda da benim için önemli olan Recall dedim ve Recall değerini arttırmak için balance işlemini yaptım.
# ve diğer skorlardan feragat etsem de recall skorumu 0.75'e yükselttim!!
#
# recall-1 hasta olanları bulma oranımızdır. bizim için hedef hasta olanları  bulmak olduğu için recall-1 için diğer scorlardan feragat ediyoruz.

# %% [markdown]
# ## Cross Validate

# %%
from sklearn.model_selection import cross_validate

# %%
model = LogisticRegression(class_weight = "balanced")  #cross val. yaparken baştan yeni bir model objecti oluşturuyorum.

scores = cross_validate(model, X_train_scaled, y_train, scoring = ['accuracy', 'precision','recall','f1'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
# df_scores
df_scores.mean()[2:]
# Out:
# test_accuracy    0.743
# test_precision   0.621
# test_recall      0.689
# test_f1          0.651
# dtype: float64

# %% [raw]
# cross validate yaparken datamdan bir miktar (test) veri çıkartıp öyle ölçümler yaptığım için data sayısı azaldığından skorlarda biraz (bazen birkaç puan) azalma olabilir. (cv = 5 yazsak muhtemel daha da düşecekti çünkü skor alırken datanın dışında tuttuğu data 5'te biri olacaktır) küçük datalarda bunu daha fazla hissederiz. ama önemli olan cross val. skoru ile ilkel skorumu kıyaslamak ve onu doğrulamak olduğu için problem yok.

# %% [markdown]
# ## ROC (Receiver Operating Curve) and AUC (Area Under Curve)

# %% [markdown]
# https://towardsdatascience.com/calculating-and-setting-thresholds-to-optimise-logistic-regression-performance-c77e6d112d7e

# %%
from sklearn.metrics import plot_roc_curve, plot_precision_recall_curve, roc_auc_score, auc, roc_curve, average_precision_score, precision_recall_curve

# %% [raw]
# Positive: 1 dediklerim, True:bildiklerim, False:bilemediklerim
#
# TRUE POSITIVE RATE (RECALL):
# True positive: Positive olarak tahmin ettiğim ve bildiğim veriler
# False positive: Positive olarak tahmin ettiğim ve yanıldığım veriler.
#
# benim 1 deyip bildiklerim gerçekte 1 olanların yüzde kaçı??
#
# FALSE POSITIVE RATE:
# Bilemediğim 1 değerlerinin tüm 1 değerlerine oranı.

# %% [raw]
# Benim bilebildiğim 1 ler ne kadar fazla ve bilemediğim 0 lar ne kadar az ise (yani aradaki farkın en yüksek olduğu yer) o zaman skorum o kadar yüksektir. o yüzden bu curve ne kadar sol üst köşe noktasına yaklaşırsa benim modelimin gücü o kadar iyi demektir.

# %%
plot_roc_curve(log_model, X_test_scaled, y_test);

# %% [raw]
# datam imbalance ise (iyi bir dağılımı yoksa) precision - recall curve e bakıyorum.. aşağıda bu grafiği görüyoruz.

# %%
plot_precision_recall_curve(log_model, X_test_scaled, y_test);

# %% [markdown]
# ## Finding Best Threshold

# %% [raw]
# Default değeri 0.5 olan "treshold" değerimi değiştirerek daha iyi bir recall değeri elde edebilir miyim ona bakıyorum.
#
# bir hyperparametre ile threshold u otomatik değiştiremiyorum o yüzden threshold değiştirme işlemini manuel olarak yapıyorum.

# %% [raw]
# TRUE POSITIVE RATE (RECALL):
# benim 1 deyip bildiklerim gerçekte 1 olanların yüzde kaçı??
# gerçekte 1 olanların yüzde kaçını bilmişim. (bildiğim 1 lerin, gerçekte tüm 1 lere oranı.)
#
# FALSE POSITIVE RATE:
# Bilemediğim 0 değerlerinin tüm 0 değerlerine oranı

# %%
plot_roc_curve(log_model, X_train_scaled, y_train);

# Dikkat! aşağıdaki grafik 1 olma durumuna göre çizildi.

# %% [raw]
# aşağıda görüyorum ki 0.5 olan threshold değerim benim en iyi değerim değil. en iyi değerim  sol üst köşe noktasına en yakın değerdir, yani 0.35.. (Bilebildiğim 1 lerin en fazla ve bilemediğim 0 lar en az (yani aradaki farkın en yüksek olduğu) yer)
#
# (en sağdaki nokta, 1 leri doğru bilmemle 0 ları doğru bildiğim nokta

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y_pred_proba = log_model.predict_proba(X_train_scaled)  # predict_proba: prediction ımın 1 ve 0 olma olasılıklarını veriyor.

roc_auc_score(y_train, y_pred_proba[:,1])

# True pos.rate-False Pos.rate curve grafiğindeki AUC=0.85 değerinin teyidi maksadıyla roc_auc_score() fonksiyonu kullanılarak bu değer tekrar bulundu.
# Out:
# 0.8455278215182177

# %%
fp_rate, tp_rate, thresholds = roc_curve(y_train, y_pred_proba[:,1])

# %%
optimal_idx = np.argmax(tp_rate - fp_rate)  # index değerini veriyor. kaç numaralı index en iyi thresholdun olduğu index.
optimal_threshold = thresholds[optimal_idx]  # bu indeksteki threshold yani best threshold değerim.
optimal_threshold
# Out:
# 0.34353888827104834

# %%
test_data.head()

# birazdan bu tabloya bir sütun daha oluşturacağım ve ona pred_2 diyeceğim. bu benim yukarda bulduğum best threshold değerine göre sonuçları verecek.
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 524            3      125             58              0        0 31.600
# 94             2      142             82             18       64 24.700
# 90             1       80             55              0        0 19.100
# 228            4      197             70             39      744 36.700
# 351            4      137             84              0        0 31.200
#
#      DiabetesPedigreeFunction  Age  Outcome  pred  pred_proba
# 524                     0.151   24        0     0       0.345
# 94                      0.761   21        0     0       0.428
# 90                      0.258   21        0     0       0.025
# 228                     2.329   31        0     1       0.990
# 351                     0.252   30        0     1       0.503

# %%
test_data["pred2"] = test_data["pred_proba"].apply(lambda x : 1 if x >= optimal_threshold else 0)

# %%
test_data.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 22             7      196             90              0        0 39.800
# 150            1      136             74             50      204 37.400
# 428            0      135             94             46      145 40.600
# 2              8      183             64              0        0 23.300
# 315            2      112             68             22       94 34.100
# 701            6      125             78             31        0 27.600
# 307            0      137             68             14      148 24.800
# 146            9       57             80             37        0 32.800
# 396            3       96             56             34      115 24.700
# 303            5      115             98              0        0 52.900
#
#      DiabetesPedigreeFunction  Age  Outcome  pred  pred_proba  pred2
# 22                      0.451   41        1     1       0.978      1
# ...

# %%
y_pred2 = test_data["pred2"]

# %%
print(confusion_matrix(y_test,y_pred2))
print(classification_report(y_test,y_pred2))
# Out:
# [[70 55]
#  [ 8 44]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.56      0.69       125
#            1       0.44      0.85      0.58        52
#
#     accuracy                           0.64       177
#    macro avg       0.67      0.70      0.64       177
# weighted avg       0.76      0.64      0.66       177

# %% [raw]
# aşağıda y_pred ile olan skorlara baktığımda pred-2 yani best threshold ile aldığım değerlerde 1 lerin recall değerinin yükseldiğini gördüm.
#
# burada (hastaları yakalama adına)  önemli olan 1 değeri olduğundan,  0 skorunun düşmesi önemli değil.

# %%
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[93 32]
#  [13 39]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.74      0.81       125
#            1       0.55      0.75      0.63        52
#
#     accuracy                           0.75       177
#    macro avg       0.71      0.75      0.72       177
# weighted avg       0.78      0.75      0.75       177

# %%
plot_precision_recall_curve(log_model, X_train_scaled, y_train);

# %% [raw]
# plot_precision_recall_curve: gerçek 1 lerin yüzde kaçını doğru bildiğim (recall) bir tarafta, bütün söylediğim 1'lerin doğru çıkma oranı (precision) diğer tarafta olarak bunları plotluyor

# %%
y_pred_proba = log_model.predict_proba(X_train_scaled)
average_precision_score(y_train, y_pred_proba[:,1])

# plot_precision_recall_curve() ile bulduğum AP = 0.73 değerini teyid etmek için average_precision_score() fonk. kullandım.
# Out:
# 0.7260867629538448

# %%
precisions, recalls, thresholds = precision_recall_curve(y_train, y_pred_proba[:,1])

# %%
optimal_idx = np.argmax((2 * precisions * recalls) / (precisions + recalls))  
optimal_threshold = thresholds[optimal_idx]
optimal_threshold

# benim precision ile recall arasındaki ilişkiyi veren zaten bir skorum var (f1_score). 
# dolayısıyla burada f1_score denklemini--> (2 * precisions * recalls) / (precisions + recalls) kullandım.
# Out:
# 0.34353888827104834

# %% [markdown]
# ## Final Model and Model Deployment

# %%
scaler = StandardScaler().fit(X)

# %%
import pickle
pickle.dump(scaler, open("scaler_diabates", 'wb'))

# X değerlerimin scale ile fit edilmiş halini scaler_diabetes te sakladım.

# %% [raw]
# Programcıları karmaşık veri türlerini saklamak için kodlamak ve hata ayıklamak ile uğraştırmak yerine Python bu iş için pickle adlı standart modülü sağlar.
#
# pickle modülü saklanabilen ve başka programlar tarafından ya da aynı programın farklı çalışma zamanlarında kullanılabilecek Python nesneleri yapmanın standart yoludur.
#
#
# Uygulamanın oluşturduğu verileri dosyaya kaydedip, tekrardan kullanmayı sağlar
# Karmaşık uygulamalarda sıklıkla yapılır
# Kaydetme işlemi text formatında değil , binary formatında olur
# w yerine wb kullanılır
# Sıklıkla pickle paketi kullanılır
# Dosya uzantısı pkl dir
#
# dump(<pickle>, <file>)
# pickle objesini dosyaya yazma
# pickle = load(<file>)
# pickle objesini dosyadan okuma

# %%
X_scaled = scaler.transform(X)

# %%
final_model = LogisticRegression(class_weight = "balanced").fit(X_scaled, y)

# %%
pickle.dump(final_model, open("final_model_diabates", 'wb'))

# %%
X.describe().T
# Out:
#                            count    mean     std    min    25%     50%  \
# Pregnancies              707.000   3.702   3.121  0.000  1.000   3.000
# Glucose                  707.000 121.734  30.657 44.000 99.000 117.000
# BloodPressure            707.000  72.481  12.012 38.000 64.000  72.000
# SkinThickness            707.000  21.296  15.422  0.000  0.000  24.000
# Insulin                  707.000  85.262 117.940  0.000  0.000  49.000
# BMI                      707.000  32.372   6.847 18.200 27.400  32.100
# DiabetesPedigreeFunction 707.000   0.476   0.334  0.078  0.245   0.378
# Age                      707.000  33.139  11.729 21.000 24.000  29.000
#
#                              75%     max
# Pregnancies                6.000  12.000
# Glucose                  141.000 199.000
# BloodPressure             80.000 122.000
# SkinThickness             33.000  63.000
# Insulin                  133.500 846.000
# BMI                       36.500  67.100
# ...

# %%
my_dict = {"Pregnancies": [3, 6, 5],
           "Glucose": [117, 140, 120],
           "BloodPressure": [72, 80, 75],
           "SkinThickness": [23, 33, 25],
           "Insulin": [48, 132, 55],
           "BMI": [32, 36.5, 34],
           "DiabetesPedigreeFunction": [0.38, 0.63, 0.45],
           "Age": [29, 40, 33]
          }

# %%
sample = pd.DataFrame(my_dict)
sample
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0            3      117             72             23       48 32.000
# 1            6      140             80             33      132 36.500
# 2            5      120             75             25       55 34.000
#
#    DiabetesPedigreeFunction  Age
# 0                     0.380   29
# 1                     0.630   40
# 2                     0.450   33

# %%
scaler_diabates = pickle.load(open("scaler_diabates", "rb"))

# %%
sample_scaled = scaler_diabates.transform(sample)
sample_scaled
# Out:
# array([[-0.22495888, -0.15452894, -0.04006354,  0.11059814, -0.31615997,
#         -0.0543865 , -0.28684307, -0.35310219],
#        [ 0.73701246,  0.59623148,  0.62640516,  0.75950177,  0.3965681 ,
#          0.60327464,  0.46316082,  0.58540625],
#        [ 0.41635535, -0.05660367,  0.20986223,  0.24037887, -0.25676596,
#          0.23790734, -0.07684198, -0.01182639]])

# %%
final_model = pickle.load(open("final_model_diabates", "rb"))

# %%
predictions = final_model.predict(sample_scaled)   # bu threshold 0.5 ile yapılmış prediction.

predictions_proba = final_model.predict_proba(sample_scaled)  # 0.5 threshold ile yapılmış prediction ların proba değeleri.

predictions2 = [1 if i >= optimal_threshold else 0 for i in predictions_proba[:,1]] # best threshold uygulayarak bulacağım 1 ve 0 lardan 1 lerin oranlarını çektim.

# %%
# yukarda bulduğum değerleri sütun haline getirip sample dataframe içinde görmek istiyorum

sample["pred_proba"] = predictions_proba[:,1]
sample["pred"] = predictions
sample["pred2"] = predictions2
sample
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0            3      117             72             23       48 32.000
# 1            6      140             80             33      132 36.500
# 2            5      120             75             25       55 34.000
#
#    DiabetesPedigreeFunction  Age  pred_proba  pred  pred2
# 0                     0.380   29       0.332     0      0
# 1                     0.630   40       0.781     1      1
# 2                     0.450   33       0.489     0      1
