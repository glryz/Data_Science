# %% [raw]
# Her bir sütuna bir feature (özellik) diyoruz. kaç tane örneklem varsa o kadar veriniz var diyebilirsin.
#
# Öncelikle outlier'ları missing value ları tespit edip onları temizlemeniz gerekir. Sütun sütun tüm outlier'ları incelememiz gerekir. Missing value larla nasıl mücadele edeceğiz, outlierlarla nasıl mücadele edeceğiz bunları iyi öğrenmek gerek.
#
# Outlier'lara neler yapabiliyorduk?
# 1. drop etmek
# 2. IQR (75% - 25% aralığı --> toplam verimizin 98%'ini içeriyor) hesaplaması ile outlierları tespit etmek.
#
# 1.5 * IQR yöntemini Mr. John Tukey bulmuş, bu bilim alanında bu katsayı kabul görmüş.
#
# İki sütunun korelasyonu çok yakın dolayısıyla aynı veriyi içeriyor diyebilirsin. Bu sütunlardan yeni bir sütun elde edip diğer ikisini silebilirsin.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("example.csv")

df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df1 = pd.read_csv('sample.csv')

df1
# Out:
#     x   w   y   z
# 0   1   2   3   4
# 1   5   6   7   8
# 2   9  10  11  12
# 3  13  14  15  16

# %%
df1.to_csv("sample_2.csv")

# ayrı bir adla kaydetttik.

# %%
pd.read_csv("sample_2.csv")


# to_csv ile kaydedince ilave bir indeks gelir.
# Out:
#    Unnamed: 0   x   w   y   z
# 0           0   1   2   3   4
# 1           1   5   6   7   8
# 2           2   9  10  11  12
# 3           3  13  14  15  16

# %%
# bu gelmesin istiyorsak read_csv() içinde index_col=0 koyacağız

pd.read_csv("sample_2.csv", index_col = 0)

# fazladan index gitti.
# Out:
#     x   w   y   z
# 0   1   2   3   4
# 1   5   6   7   8
# 2   9  10  11  12
# 3  13  14  15  16

# %%
df_tit = pd.read_csv("titanic.csv")

df_tit
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
# pd.read_csv("titanic.csv", sep= "\t")

# datasetim virgülle değil (csv değil) \ ile ayrılmış olduğu için. sep=\"t" yaparak bu durumu çözdük.

# %%
df_tit.to_json("json_titanic.json")

# %%
pd.read_json("json_titanic.json")
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
with open("ornekcsv.csv", "r", encoding="utf-8") as f:
    print(f.read())
# Out:
# a;b;c
# 78;12;1
# 78;12;2
# 78;324;3
# 7;2;4
# 88;23;5
# 6;2;
# 56;11;6
# 7;12;7
# 56;21;7
# 346;2;8
# 5;1;8
# 456;21;8
# 3;12;88

# %%
ornek = pd.read_csv("ornekcsv.csv", sep = ";")

# yukarda veriler arasında gördüğün ; ları read_csv yaparken attık ve görünümü düzeltmiş olmuş olduk. 
# üzerinde çalışıp değişiklik yapacağım için değişkene atadım. onun üzerinde çalışacağım.

# %%
ornek
# Out:
#       a    b     c
# 0    78   12   1.0
# 1    78   12   2.0
# 2    78  324   3.0
# 3     7    2   4.0
# 4    88   23   5.0
# 5     6    2   NaN
# 6    56   11   6.0
# 7     7   12   7.0
# 8    56   21   7.0
# 9   346    2   8.0
# 10    5    1   8.0
# 11  456   21   8.0
# 12    3   12  88.0

# %%
ornek.to_csv("ornekcsv_2.csv")

# to_csv ile kaydettiğim için ilave index sütunu ekleyecek.

# %%
pd.read_csv("ornekcsv_2.csv")

# Unnamed adında ilave index sütunu ekledi.
# Out:
#     Unnamed: 0    a    b     c
# 0            0   78   12   1.0
# 1            1   78   12   2.0
# 2            2   78  324   3.0
# 3            3    7    2   4.0
# 4            4   88   23   5.0
# 5            5    6    2   NaN
# 6            6   56   11   6.0
# 7            7    7   12   7.0
# 8            8   56   21   7.0
# 9            9  346    2   8.0
# 10          10    5    1   8.0
# 11          11  456   21   8.0
# 12          12    3   12  88.0

# %%
ornek.to_csv("ornekcsv_3.csv", index = False)

#  index = False koyduğum için ilave index sütunu görmeyeceğim

# %%
pd.read_csv("ornekcsv_3.csv")

# ilave index sütunu yok.
# Out:
#       a    b     c
# 0    78   12   1.0
# 1    78   12   2.0
# 2    78  324   3.0
# 3     7    2   4.0
# 4    88   23   5.0
# 5     6    2   NaN
# 6    56   11   6.0
# 7     7   12   7.0
# 8    56   21   7.0
# 9   346    2   8.0
# 10    5    1   8.0
# 11  456   21   8.0
# 12    3   12  88.0

# %%
ornek.to_csv("ornekcsv_4.csv")

# %%
pd.read_csv("ornekcsv_4.csv", index_col=0)

# to_csv'nin getirdiği ilave index sütununu  okurken de (read_csv) kaldırabiliriz. bunun için index_col = 0 yapıyoruz.
# Out:
#       a    b     c
# 0    78   12   1.0
# 1    78   12   2.0
# 2    78  324   3.0
# 3     7    2   4.0
# 4    88   23   5.0
# 5     6    2   NaN
# 6    56   11   6.0
# 7     7   12   7.0
# 8    56   21   7.0
# 9   346    2   8.0
# 10    5    1   8.0
# 11  456   21   8.0
# 12    3   12  88.0

# %% [raw]
# ilave index sütununu görmemek için:
#
# to_csv'de    -->  index = False
#
# read_csv'de  -->  index_col  = 0

# %% [markdown]
# Çalıştığın dosyada boş satırlar varsa ve bunun görünmesini istiyorsan (çıkartılmasını istemiyorsan) skip_blank_lines = False yapacaksın.

# %% [markdown]
# ## Excel dosyasını okuma - yazma

# %%
df = pd.read_excel("Excel_Sample.xlsx")

df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df1 = pd.read_excel("Excel_Sample.xlsx", sheet_name = "Sheet2")

# sheet_name ile herhangi bir sheet'i açabiliriz.

df1
# Out:
#     a   b    c   d
# 0  11  55  123   3
# 1  22  66  234   7
# 2  33  77  456  11
# 3  44  88  678  15

# %%
# ya da sheetlerin index numaralarını da belirterek istediğimiz sheeti açabiliriz.

df1 = pd.read_excel("Excel_Sample.xlsx", sheet_name = 0)

df1
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_excel("ornekx.xlsx")

# satırlardan herhangi birinde Nan olduğunda tüm sütunu float yapıyor. 
# NaN verilerin float olma ihtimaline karşı tüm veriyi float yapıyor.
# Out:
#         a      b     c
# 0    78.0   12.0   1.0
# 1    78.0   12.0   2.0
# 2    78.0  324.0   3.0
# 3     7.0    2.0   4.0
# 4     NaN   23.0   5.0
# 5     6.0    2.0   NaN
# 6     NaN   11.0   6.0
# 7     7.0   12.0   7.0
# 8    56.0   21.0   7.0
# 9   346.0    NaN   8.0
# 10    5.0    1.0   8.0
# 11  456.0   21.0   8.0
# 12    3.0   12.0  88.0

# %%
df.to_excel("Excel_Sample_1.xlsx", sheet_name = "Sheet-1", index = False)

# to_excel ile dosyayı içindeki sheetin ismi Sheet-1 olacak şekilde Excel_Sample_1.xlsx olarak kaydettik.
